# %% [markdown]
# ## Named Entity Recognition and De-Identification with SpaCy

# %% [markdown]
# #### Importing Libraries

# %%
import requests
from bs4 import BeautifulSoup
import spacy
from spacy import displacy
import random
import en_core_web_sm
from collections import Counter
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords
import pandas as pd
import nltk

# %% [markdown]
# ### TASK-01

# %% [markdown]
# ##### 1.1 Scrapring webpage

# %%
r = requests.get("https://www.nbcnews.com/news/world/hong-kong-finance-summit-covid-rcna55498")
soup = BeautifulSoup(r.content,  "html.parser")
soup = soup.find('div',class_='article-body__content')
text = soup.get_text()
print(text[:500],'.....')
# Out:
# HONG KONG — After mass unrest in 2019, a pandemic that left it isolated from the world and the imposition of a national security law that has crushed dissent, Hong Kong is ready to turn the page. “Social disturbance is clearly in the past,” the city’s leader, John Lee, said Wednesday at the Four Seasons Hotel, where about 200 finance industry executives from around the world were gathered for a summit. “It has given way to stability, to growing business and community confidence in Hong Kong’s fu .....

# %% [markdown]
# ##### 1.2 NER in SpaCy

# %% [markdown]
# ###### 1.2.1 Named Entities

# %%
nlp = en_core_web_sm.load()
spacy_obj= nlp(text)
# Out:
# C:\Users\Vikas\anaconda3\lib\site-packages\spacy\language.py:1895: UserWarning: [W123] Argument disable with value [] is used instead of ['senter'] as specified in the config. Be aware that this might affect other components in your pipeline.
#   warnings.warn(

# %%
## Entity counts
print('Entity counts:')
# Count every named entity
labels = [x.label_ for x in spacy_obj.ents]
from collections import Counter
counts = Counter(labels)
print(counts)
# Out:
# Entity counts:
# Counter({'GPE': 51, 'DATE': 33, 'PERSON': 30, 'CARDINAL': 15, 'ORG': 12, 'NORP': 10, 'LOC': 2, 'PERCENT': 2, 'FAC': 1, 'ORDINAL': 1})

# %%
## Entities
print('Entitites:')
for x in spacy_obj.ents:
  print(dict(text=x.text, label=x.label_, start_char=x.start_char, end_char=x.start_char+len(x.text)))
# Out:
# Entitites:
# {'text': 'HONG KONG', 'label': 'GPE', 'start_char': 0, 'end_char': 9}
# {'text': '2019', 'label': 'DATE', 'start_char': 33, 'end_char': 37}
# {'text': 'Hong Kong', 'label': 'GPE', 'start_char': 159, 'end_char': 168}
# {'text': 'John Lee', 'label': 'PERSON', 'start_char': 260, 'end_char': 268}
# {'text': 'Wednesday', 'label': 'DATE', 'start_char': 275, 'end_char': 284}
# {'text': 'the Four Seasons Hotel', 'label': 'ORG', 'start_char': 288, 'end_char': 310}
# {'text': 'about 200', 'label': 'CARDINAL', 'start_char': 318, 'end_char': 327}
# {'text': 'Hong Kong’s', 'label': 'GPE', 'start_char': 486, 'end_char': 497}
# {'text': 'Chinese', 'label': 'NORP', 'start_char': 600, 'end_char': 607}
# {'text': 'Hong Kong’s', 'label': 'GPE', 'start_char': 738, 'end_char': 749}
# {'text': 'China', 'label': 'GPE', 'start_char': 771, 'end_char': 776}
# {'text': 'American', 'label': 'NORP', 'start_char': 902, 'end_char': 910}
# {'text': 'China', 'label': 'GPE', 'start_char': 1004, 'end_char': 1009}
# {'text': 'U.S.', 'label': 'GPE', 'start_char': 1087, 'end_char': 1091}
# {'text': 'Lee', 'label': 'PERSON', 'start_char': 1111, 'end_char': 1114}
# {'text': 'John Lee', 'label': 'PERSON', 'start_char': 1190, 'end_char': 1198}
# {'text': 'Hong Kong’s', 'label': 'GPE', 'start_char': 1200, 'end_char': 1211}
# {'text': 'Wednesday', 'label': 'DATE', 'start_char': 1257, 'end_char': 1266}
# {'text': 'Paul Yeung', 'label': 'PERSON', 'start_char': 1268, 'end_char': 1278}
# {'text': 'Bloomberg', 'label': 'PERSON', 'start_char': 1281, 'end_char': 1290}
# {'text': 'week', 'label': 'DATE', 'start_char': 1360, 'end_char': 1364}
# {'text': 'Monday', 'label': 'DATE', 'start_char': 1392, 'end_char': 1398}
# {'text': 'this weekend', 'label': 'DATE', 'start_char': 1438, 'end_char': 1450}
# {'text': 'Sevens', 'label': 'PERSON', 'start_char': 1518, 'end_char': 1524}
# {'text': 'Iñaki Amate', 'label': 'PERSON', 'start_char': 1536, 'end_char': 1547}
# {'text': 'the European Chamber of Commerce', 'label': 'ORG', 'start_char': 1561, 'end_char': 1593}
# {'text': 'Hong Kong', 'label': 'GPE', 'start_char': 1597, 'end_char': 1606}
# {'text': 'Amate', 'label': 'ORG', 'start_char': 1770, 'end_char': 1775}
# {'text': 'Tuesday', 'label': 'DATE', 'start_char': 1781, 'end_char': 1788}
# {'text': 'Hong Kong', 'label': 'GPE', 'start_char': 2042, 'end_char': 2051}
# {'text': '7.3 million', 'label': 'CARDINAL', 'start_char': 2090, 'end_char': 2101}
# {'text': 'Asia', 'label': 'LOC', 'start_char': 2172, 'end_char': 2176}
# {'text': 'Covid', 'label': 'PERSON', 'start_char': 2218, 'end_char': 2223}
# {'text': 'Chinese', 'label': 'NORP', 'start_char': 2349, 'end_char': 2356}
# {'text': 'Hong Kong', 'label': 'GPE', 'start_char': 2374, 'end_char': 2383}
# {'text': '25 years', 'label': 'DATE', 'start_char': 2384, 'end_char': 2392}
# {'text': 'Britain', 'label': 'GPE', 'start_char': 2399, 'end_char': 2406}
# {'text': 'July 2', 'label': 'DATE', 'start_char': 2417, 'end_char': 2423}
# {'text': 'about 319,000', 'label': 'CARDINAL', 'start_char': 2555, 'end_char': 2568}
# {'text': 'Hong Kong', 'label': 'GPE', 'start_char': 2587, 'end_char': 2596}
# {'text': 'last month', 'label': 'DATE', 'start_char': 2597, 'end_char': 2607}
# {'text': '97%', 'label': 'PERCENT', 'start_char': 2614, 'end_char': 2617}
# {'text': '10.8 million', 'label': 'CARDINAL', 'start_char': 2623, 'end_char': 2635}
# {'text': 'October 2019', 'label': 'DATE', 'start_char': 2639, 'end_char': 2651}
# {'text': 'Hong Kong', 'label': 'GPE', 'start_char': 2734, 'end_char': 2743}
# {'text': 'Covid', 'label': 'PERSON', 'start_char': 2750, 'end_char': 2755}
# {'text': '4.5%', 'label': 'PERCENT', 'start_char': 2812, 'end_char': 2816}
# {'text': 'the third quarter', 'label': 'DATE', 'start_char': 2820, 'end_char': 2837}
# {'text': 'one', 'label': 'CARDINAL', 'start_char': 2941, 'end_char': 2944}
# {'text': 'last month', 'label': 'DATE', 'start_char': 2952, 'end_char': 2962}
# {'text': 'Hong Kong', 'label': 'GPE', 'start_char': 2964, 'end_char': 2973}
# {'text': 'Asia', 'label': 'LOC', 'start_char': 2997, 'end_char': 3001}
# {'text': 'Singapore', 'label': 'GPE', 'start_char': 3028, 'end_char': 3037}
# {'text': 'daily', 'label': 'DATE', 'start_char': 3053, 'end_char': 3058}
# {'text': '2019', 'label': 'DATE', 'start_char': 3096, 'end_char': 3100}
# {'text': 'more than 10,000', 'label': 'CARDINAL', 'start_char': 3136, 'end_char': 3152}
# {'text': 'the last two months alone', 'label': 'DATE', 'start_char': 3183, 'end_char': 3208}
# {'text': 'Hong Kong', 'label': 'GPE', 'start_char': 3210, 'end_char': 3219}
# {'text': '90-year-old', 'label': 'DATE', 'start_char': 3230, 'end_char': 3241}
# {'text': 'Roman Catholic', 'label': 'NORP', 'start_char': 3242, 'end_char': 3256}
# {'text': 'five', 'label': 'CARDINAL', 'start_char': 3318, 'end_char': 3322}
# {'text': 'two', 'label': 'CARDINAL', 'start_char': 3383, 'end_char': 3386}
# {'text': 'Jimmy Lai', 'label': 'PERSON', 'start_char': 3495, 'end_char': 3504}
# {'text': 'the United States', 'label': 'GPE', 'start_char': 3527, 'end_char': 3544}
# {'text': 'Hong Kong', 'label': 'GPE', 'start_char': 3570, 'end_char': 3579}
# {'text': 'Jimmy Lai', 'label': 'PERSON', 'start_char': 3616, 'end_char': 3625}
# {'text': '75', 'label': 'DATE', 'start_char': 3627, 'end_char': 3629}
# {'text': 'last month', 'label': 'DATE', 'start_char': 3645, 'end_char': 3655}
# {'text': 'the United States', 'label': 'GPE', 'start_char': 3678, 'end_char': 3695}
# {'text': 'Wallace', 'label': 'PERSON', 'start_char': 3722, 'end_char': 3729}
# {'text': '200', 'label': 'CARDINAL', 'start_char': 3766, 'end_char': 3769}
# {'text': 'Lai', 'label': 'PERSON', 'start_char': 3788, 'end_char': 3791}
# {'text': 'Beijing', 'label': 'GPE', 'start_char': 3854, 'end_char': 3861}
# {'text': '2020', 'label': 'DATE', 'start_char': 3873, 'end_char': 3877}
# {'text': 'U.S.', 'label': 'GPE', 'start_char': 3911, 'end_char': 3915}
# {'text': 'Hong Kong', 'label': 'GPE', 'start_char': 4046, 'end_char': 4055}
# {'text': 'Chinese', 'label': 'NORP', 'start_char': 4060, 'end_char': 4067}
# {'text': 'China', 'label': 'GPE', 'start_char': 4189, 'end_char': 4194}
# {'text': 'Hong Kong', 'label': 'GPE', 'start_char': 4285, 'end_char': 4294}
# {'text': 'Brian Kern', 'label': 'PERSON', 'start_char': 4325, 'end_char': 4335}
# {'text': 'Hong Kong', 'label': 'GPE', 'start_char': 4391, 'end_char': 4400}
# {'text': 'last month', 'label': 'DATE', 'start_char': 4420, 'end_char': 4430}
# {'text': 'the Hong Kong Democracy Council', 'label': 'ORG', 'start_char': 4434, 'end_char': 4465}
# {'text': 'Washington', 'label': 'GPE', 'start_char': 4494, 'end_char': 4504}
# {'text': 'Hong Kong', 'label': 'GPE', 'start_char': 4558, 'end_char': 4567}
# {'text': 'U.N.', 'label': 'ORG', 'start_char': 4768, 'end_char': 4772}
# {'text': 'Kern', 'label': 'PERSON', 'start_char': 4815, 'end_char': 4819}
# {'text': 'Hong Kong', 'label': 'GPE', 'start_char': 4845, 'end_char': 4854}
# {'text': 'June 4, 2021', 'label': 'DATE', 'start_char': 4858, 'end_char': 4870}
# {'text': 'annual', 'label': 'DATE', 'start_char': 4886, 'end_char': 4892}
# {'text': 'Tiananmen Square', 'label': 'FAC', 'start_char': 4918, 'end_char': 4934}
# {'text': 'Beijing', 'label': 'GPE', 'start_char': 4947, 'end_char': 4954}
# {'text': 'Paul Yeung', 'label': 'PERSON', 'start_char': 4955, 'end_char': 4965}
# {'text': 'Bloomberg', 'label': 'PERSON', 'start_char': 4968, 'end_char': 4977}
# {'text': 'Getty Images', 'label': 'ORG', 'start_char': 4982, 'end_char': 4994}
# {'text': 'Hong Kong', 'label': 'GPE', 'start_char': 5072, 'end_char': 5081}
# {'text': 'Chinese', 'label': 'NORP', 'start_char': 5101, 'end_char': 5108}
# {'text': 'Global Times', 'label': 'ORG', 'start_char': 5142, 'end_char': 5154}
# {'text': 'Thursday', 'label': 'DATE', 'start_char': 5158, 'end_char': 5166}
# {'text': '”Hong Kong', 'label': 'GPE', 'start_char': 5265, 'end_char': 5275}
# {'text': 'Allan Zeman', 'label': 'PERSON', 'start_char': 5343, 'end_char': 5354}
# {'text': 'Hong Kong', 'label': 'GPE', 'start_char': 5395, 'end_char': 5404}
# {'text': 'China', 'label': 'GPE', 'start_char': 5487, 'end_char': 5492}
# {'text': 'Zeman', 'label': 'ORG', 'start_char': 5517, 'end_char': 5522}
# {'text': '2019', 'label': 'DATE', 'start_char': 5614, 'end_char': 5618}
# {'text': 'about 200', 'label': 'CARDINAL', 'start_char': 5775, 'end_char': 5784}
# {'text': 'more than 100', 'label': 'CARDINAL', 'start_char': 5803, 'end_char': 5816}
# {'text': 'Paul Yeung', 'label': 'PERSON', 'start_char': 5846, 'end_char': 5856}
# {'text': 'Bloomberg', 'label': 'PERSON', 'start_char': 5859, 'end_char': 5868}
# {'text': 'Getty ImagesKern', 'label': 'PERSON', 'start_char': 5873, 'end_char': 5889}
# {'text': '”“I', 'label': 'PERSON', 'start_char': 6011, 'end_char': 6014}
# {'text': 'Hong Kong', 'label': 'GPE', 'start_char': 6039, 'end_char': 6048}
# {'text': 'Last week', 'label': 'DATE', 'start_char': 6165, 'end_char': 6174}
# {'text': 'Hong Kong', 'label': 'GPE', 'start_char': 6176, 'end_char': 6185}
# {'text': '20', 'label': 'CARDINAL', 'start_char': 6206, 'end_char': 6208}
# {'text': 'World Justice Project', 'label': 'ORG', 'start_char': 6276, 'end_char': 6297}
# {'text': 'Hong Kong', 'label': 'GPE', 'start_char': 6363, 'end_char': 6372}
# {'text': 'sixth', 'label': 'ORDINAL', 'start_char': 6444, 'end_char': 6449}
# {'text': 'Lee', 'label': 'PERSON', 'start_char': 6473, 'end_char': 6476}
# {'text': 'Hong Kong', 'label': 'GPE', 'start_char': 6482, 'end_char': 6491}
# {'text': 'one', 'label': 'CARDINAL', 'start_char': 6568, 'end_char': 6571}
# {'text': 'two', 'label': 'CARDINAL', 'start_char': 6581, 'end_char': 6584}
# {'text': 'Hong Kong', 'label': 'GPE', 'start_char': 6630, 'end_char': 6639}
# {'text': 'British', 'label': 'NORP', 'start_char': 6650, 'end_char': 6657}
# {'text': 'Chinese', 'label': 'NORP', 'start_char': 6678, 'end_char': 6685}
# {'text': '1997.“Hong Kong', 'label': 'GPE', 'start_char': 6694, 'end_char': 6709}
# {'text': 'China', 'label': 'GPE', 'start_char': 6781, 'end_char': 6786}
# {'text': 'Lee', 'label': 'PERSON', 'start_char': 6838, 'end_char': 6841}
# {'text': 'September', 'label': 'DATE', 'start_char': 6870, 'end_char': 6879}
# {'text': 'Hong Kong', 'label': 'GPE', 'start_char': 6889, 'end_char': 6898}
# {'text': 'Singapore', 'label': 'GPE', 'start_char': 6906, 'end_char': 6915}
# {'text': 'the Fraser Institute', 'label': 'ORG', 'start_char': 6951, 'end_char': 6971}
# {'text': 'Canadian', 'label': 'NORP', 'start_char': 6977, 'end_char': 6985}
# {'text': 'Hong Kong’s', 'label': 'GPE', 'start_char': 7034, 'end_char': 7045}
# {'text': '2020', 'label': 'DATE', 'start_char': 7106, 'end_char': 7110}
# {'text': 'China', 'label': 'GPE', 'start_char': 7167, 'end_char': 7172}
# {'text': 'Hong Kong', 'label': 'GPE', 'start_char': 7208, 'end_char': 7217}
# {'text': 'Tuesday', 'label': 'DATE', 'start_char': 7221, 'end_char': 7228}
# {'text': 'Peter Parks', 'label': 'PERSON', 'start_char': 7230, 'end_char': 7241}
# {'text': 'Covid', 'label': 'NORP', 'start_char': 7398, 'end_char': 7403}
# {'text': 'Lee', 'label': 'PERSON', 'start_char': 7427, 'end_char': 7430}
# {'text': 'Hong Kong', 'label': 'GPE', 'start_char': 7463, 'end_char': 7472}
# {'text': 'September', 'label': 'DATE', 'start_char': 7502, 'end_char': 7511}
# {'text': 'Lee', 'label': 'PERSON', 'start_char': 7518, 'end_char': 7521}
# {'text': 'one', 'label': 'CARDINAL', 'start_char': 7599, 'end_char': 7602}
# {'text': '21 days', 'label': 'DATE', 'start_char': 7621, 'end_char': 7628}
# {'text': 'Covid', 'label': 'PERSON', 'start_char': 7707, 'end_char': 7712}
# {'text': 'Amate', 'label': 'ORG', 'start_char': 7748, 'end_char': 7753}
# {'text': 'the first three days', 'label': 'DATE', 'start_char': 8002, 'end_char': 8022}
# {'text': 'Hong Kong’s', 'label': 'GPE', 'start_char': 8305, 'end_char': 8316}
# {'text': 'Paul Chan', 'label': 'PERSON', 'start_char': 8338, 'end_char': 8347}
# {'text': 'this week', 'label': 'DATE', 'start_char': 8382, 'end_char': 8391}
# {'text': 'Saudi Arabia', 'label': 'GPE', 'start_char': 8452, 'end_char': 8464}
# {'text': 'Hong Kong’s', 'label': 'GPE', 'start_char': 8518, 'end_char': 8529}
# {'text': 'China', 'label': 'GPE', 'start_char': 8633, 'end_char': 8638}
# {'text': 'Heiwai Tang', 'label': 'PERSON', 'start_char': 8747, 'end_char': 8758}
# {'text': 'the University of Hong Kong', 'label': 'ORG', 'start_char': 8786, 'end_char': 8813}

# %%
## Token labels
print('Token-labels:')
for x in spacy_obj:
  print(dict(text=x, prefix=x.ent_iob_, entity_type=x.ent_type_))
# Out:
# Token-labels:
# {'text': HONG, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': KONG, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': —, 'prefix': 'O', 'entity_type': ''}
# {'text': After, 'prefix': 'O', 'entity_type': ''}
# {'text': mass, 'prefix': 'O', 'entity_type': ''}
# {'text': unrest, 'prefix': 'O', 'entity_type': ''}
# {'text': in, 'prefix': 'O', 'entity_type': ''}
# {'text': 2019, 'prefix': 'B', 'entity_type': 'DATE'}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': a, 'prefix': 'O', 'entity_type': ''}
# {'text': pandemic, 'prefix': 'O', 'entity_type': ''}
# {'text': that, 'prefix': 'O', 'entity_type': ''}
# {'text': left, 'prefix': 'O', 'entity_type': ''}
# {'text': it, 'prefix': 'O', 'entity_type': ''}
# {'text': isolated, 'prefix': 'O', 'entity_type': ''}
# {'text': from, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': world, 'prefix': 'O', 'entity_type': ''}
# {'text': and, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': imposition, 'prefix': 'O', 'entity_type': ''}
# {'text': of, 'prefix': 'O', 'entity_type': ''}
# {'text': a, 'prefix': 'O', 'entity_type': ''}
# {'text': national, 'prefix': 'O', 'entity_type': ''}
# {'text': security, 'prefix': 'O', 'entity_type': ''}
# {'text': law, 'prefix': 'O', 'entity_type': ''}
# {'text': that, 'prefix': 'O', 'entity_type': ''}
# {'text': has, 'prefix': 'O', 'entity_type': ''}
# {'text': crushed, 'prefix': 'O', 'entity_type': ''}
# {'text': dissent, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': Hong, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': Kong, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': is, 'prefix': 'O', 'entity_type': ''}
# {'text': ready, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': turn, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': page, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text':  , 'prefix': 'O', 'entity_type': ''}
# {'text': “, 'prefix': 'O', 'entity_type': ''}
# {'text': Social, 'prefix': 'O', 'entity_type': ''}
# {'text': disturbance, 'prefix': 'O', 'entity_type': ''}
# {'text': is, 'prefix': 'O', 'entity_type': ''}
# {'text': clearly, 'prefix': 'O', 'entity_type': ''}
# {'text': in, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': past, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': ”, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': city, 'prefix': 'O', 'entity_type': ''}
# {'text': ’s, 'prefix': 'O', 'entity_type': ''}
# {'text': leader, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': John, 'prefix': 'B', 'entity_type': 'PERSON'}
# {'text': Lee, 'prefix': 'I', 'entity_type': 'PERSON'}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': said, 'prefix': 'O', 'entity_type': ''}
# {'text': Wednesday, 'prefix': 'B', 'entity_type': 'DATE'}
# {'text': at, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'B', 'entity_type': 'ORG'}
# {'text': Four, 'prefix': 'I', 'entity_type': 'ORG'}
# {'text': Seasons, 'prefix': 'I', 'entity_type': 'ORG'}
# {'text': Hotel, 'prefix': 'I', 'entity_type': 'ORG'}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': where, 'prefix': 'O', 'entity_type': ''}
# {'text': about, 'prefix': 'B', 'entity_type': 'CARDINAL'}
# {'text': 200, 'prefix': 'I', 'entity_type': 'CARDINAL'}
# {'text': finance, 'prefix': 'O', 'entity_type': ''}
# {'text': industry, 'prefix': 'O', 'entity_type': ''}
# {'text': executives, 'prefix': 'O', 'entity_type': ''}
# {'text': from, 'prefix': 'O', 'entity_type': ''}
# {'text': around, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': world, 'prefix': 'O', 'entity_type': ''}
# {'text': were, 'prefix': 'O', 'entity_type': ''}
# {'text': gathered, 'prefix': 'O', 'entity_type': ''}
# {'text': for, 'prefix': 'O', 'entity_type': ''}
# {'text': a, 'prefix': 'O', 'entity_type': ''}
# {'text': summit, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': “, 'prefix': 'O', 'entity_type': ''}
# {'text': It, 'prefix': 'O', 'entity_type': ''}
# {'text': has, 'prefix': 'O', 'entity_type': ''}
# {'text': given, 'prefix': 'O', 'entity_type': ''}
# {'text': way, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': stability, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': growing, 'prefix': 'O', 'entity_type': ''}
# {'text': business, 'prefix': 'O', 'entity_type': ''}
# {'text': and, 'prefix': 'O', 'entity_type': ''}
# {'text': community, 'prefix': 'O', 'entity_type': ''}
# {'text': confidence, 'prefix': 'O', 'entity_type': ''}
# {'text': in, 'prefix': 'O', 'entity_type': ''}
# {'text': Hong, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': Kong, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': ’s, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': future, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': Law, 'prefix': 'O', 'entity_type': ''}
# {'text': and, 'prefix': 'O', 'entity_type': ''}
# {'text': order, 'prefix': 'O', 'entity_type': ''}
# {'text': has, 'prefix': 'O', 'entity_type': ''}
# {'text': returned, 'prefix': 'O', 'entity_type': ''}
# {'text': ;, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': worst, 'prefix': 'O', 'entity_type': ''}
# {'text': is, 'prefix': 'O', 'entity_type': ''}
# {'text': behind, 'prefix': 'O', 'entity_type': ''}
# {'text': us, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': ”But, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': summit, 'prefix': 'O', 'entity_type': ''}
# {'text': —, 'prefix': 'O', 'entity_type': ''}
# {'text': meant, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': signal, 'prefix': 'O', 'entity_type': ''}
# {'text': that, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': Chinese, 'prefix': 'B', 'entity_type': 'NORP'}
# {'text': territory, 'prefix': 'O', 'entity_type': ''}
# {'text': long, 'prefix': 'O', 'entity_type': ''}
# {'text': known, 'prefix': 'O', 'entity_type': ''}
# {'text': as, 'prefix': 'O', 'entity_type': ''}
# {'text': a, 'prefix': 'O', 'entity_type': ''}
# {'text': regional, 'prefix': 'O', 'entity_type': ''}
# {'text': financial, 'prefix': 'O', 'entity_type': ''}
# {'text': powerhouse, 'prefix': 'O', 'entity_type': ''}
# {'text': is, 'prefix': 'O', 'entity_type': ''}
# {'text': again, 'prefix': 'O', 'entity_type': ''}
# {'text': open, 'prefix': 'O', 'entity_type': ''}
# {'text': for, 'prefix': 'O', 'entity_type': ''}
# {'text': business, 'prefix': 'O', 'entity_type': ''}
# {'text': —, 'prefix': 'O', 'entity_type': ''}
# {'text': has, 'prefix': 'O', 'entity_type': ''}
# {'text': been, 'prefix': 'O', 'entity_type': ''}
# {'text': shadowed, 'prefix': 'O', 'entity_type': ''}
# {'text': by, 'prefix': 'O', 'entity_type': ''}
# {'text': some, 'prefix': 'O', 'entity_type': ''}
# {'text': awkward, 'prefix': 'O', 'entity_type': ''}
# {'text': realities, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text':  , 'prefix': 'O', 'entity_type': ''}
# {'text': Hong, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': Kong, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': ’s, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': border, 'prefix': 'O', 'entity_type': ''}
# {'text': with, 'prefix': 'O', 'entity_type': ''}
# {'text': mainland, 'prefix': 'O', 'entity_type': ''}
# {'text': China, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': its, 'prefix': 'O', 'entity_type': ''}
# {'text': main, 'prefix': 'O', 'entity_type': ''}
# {'text': economic, 'prefix': 'O', 'entity_type': ''}
# {'text': driver, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': remains, 'prefix': 'O', 'entity_type': ''}
# {'text': tightly, 'prefix': 'O', 'entity_type': ''}
# {'text': closed, 'prefix': 'O', 'entity_type': ''}
# {'text': because, 'prefix': 'O', 'entity_type': ''}
# {'text': of, 'prefix': 'O', 'entity_type': ''}
# {'text': pandemic, 'prefix': 'O', 'entity_type': ''}
# {'text': restrictions, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': Participants, 'prefix': 'O', 'entity_type': ''}
# {'text': in, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': summit, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': many, 'prefix': 'O', 'entity_type': ''}
# {'text': of, 'prefix': 'O', 'entity_type': ''}
# {'text': them, 'prefix': 'O', 'entity_type': ''}
# {'text': American, 'prefix': 'B', 'entity_type': 'NORP'}
# {'text': companies, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': have, 'prefix': 'O', 'entity_type': ''}
# {'text': been, 'prefix': 'O', 'entity_type': ''}
# {'text': criticized, 'prefix': 'O', 'entity_type': ''}
# {'text': by, 'prefix': 'O', 'entity_type': ''}
# {'text': rights, 'prefix': 'O', 'entity_type': ''}
# {'text': groups, 'prefix': 'O', 'entity_type': ''}
# {'text': and, 'prefix': 'O', 'entity_type': ''}
# {'text': lawmakers, 'prefix': 'O', 'entity_type': ''}
# {'text': who, 'prefix': 'O', 'entity_type': ''}
# {'text': say, 'prefix': 'O', 'entity_type': ''}
# {'text': they, 'prefix': 'O', 'entity_type': ''}
# {'text': are, 'prefix': 'O', 'entity_type': ''}
# {'text': complicit, 'prefix': 'O', 'entity_type': ''}
# {'text': in, 'prefix': 'O', 'entity_type': ''}
# {'text': China, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': ’s, 'prefix': 'O', 'entity_type': ''}
# {'text': harsh, 'prefix': 'O', 'entity_type': ''}
# {'text': crackdown, 'prefix': 'O', 'entity_type': ''}
# {'text': on, 'prefix': 'O', 'entity_type': ''}
# {'text': pro, 'prefix': 'O', 'entity_type': ''}
# {'text': -, 'prefix': 'O', 'entity_type': ''}
# {'text': democracy, 'prefix': 'O', 'entity_type': ''}
# {'text': figures, 'prefix': 'O', 'entity_type': ''}
# {'text': and, 'prefix': 'O', 'entity_type': ''}
# {'text': groups, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': And, 'prefix': 'O', 'entity_type': ''}
# {'text': as, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': subject, 'prefix': 'O', 'entity_type': ''}
# {'text': of, 'prefix': 'O', 'entity_type': ''}
# {'text': U.S., 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': sanctions, 'prefix': 'O', 'entity_type': ''}
# {'text': himself, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': Lee, 'prefix': 'B', 'entity_type': 'PERSON'}
# {'text': is, 'prefix': 'O', 'entity_type': ''}
# {'text': unable, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': hold, 'prefix': 'O', 'entity_type': ''}
# {'text': an, 'prefix': 'O', 'entity_type': ''}
# {'text': account, 'prefix': 'O', 'entity_type': ''}
# {'text': with, 'prefix': 'O', 'entity_type': ''}
# {'text': many, 'prefix': 'O', 'entity_type': ''}
# {'text': of, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': very, 'prefix': 'O', 'entity_type': ''}
# {'text': banks, 'prefix': 'O', 'entity_type': ''}
# {'text': he, 'prefix': 'O', 'entity_type': ''}
# {'text': was, 'prefix': 'O', 'entity_type': ''}
# {'text': addressing, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': John, 'prefix': 'B', 'entity_type': 'PERSON'}
# {'text': Lee, 'prefix': 'I', 'entity_type': 'PERSON'}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': Hong, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': Kong, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': ’s, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': top, 'prefix': 'O', 'entity_type': ''}
# {'text': leader, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': center, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': at, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': finance, 'prefix': 'O', 'entity_type': ''}
# {'text': summit, 'prefix': 'O', 'entity_type': ''}
# {'text': on, 'prefix': 'O', 'entity_type': ''}
# {'text': Wednesday, 'prefix': 'B', 'entity_type': 'DATE'}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': Paul, 'prefix': 'B', 'entity_type': 'PERSON'}
# {'text': Yeung, 'prefix': 'I', 'entity_type': 'PERSON'}
# {'text': /, 'prefix': 'O', 'entity_type': ''}
# {'text': Bloomberg, 'prefix': 'B', 'entity_type': 'PERSON'}
# {'text': via, 'prefix': 'O', 'entity_type': ''}
# {'text': Getty, 'prefix': 'O', 'entity_type': ''}
# {'text': ImagesNone, 'prefix': 'O', 'entity_type': ''}
# {'text': of, 'prefix': 'O', 'entity_type': ''}
# {'text': that, 'prefix': 'O', 'entity_type': ''}
# {'text': seems, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': have, 'prefix': 'O', 'entity_type': ''}
# {'text': dampened, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': mood, 'prefix': 'O', 'entity_type': ''}
# {'text': at, 'prefix': 'O', 'entity_type': ''}
# {'text': this, 'prefix': 'O', 'entity_type': ''}
# {'text': week, 'prefix': 'B', 'entity_type': 'DATE'}
# {'text': ’s, 'prefix': 'O', 'entity_type': ''}
# {'text': events, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': which, 'prefix': 'O', 'entity_type': ''}
# {'text': started, 'prefix': 'O', 'entity_type': ''}
# {'text': on, 'prefix': 'O', 'entity_type': ''}
# {'text': Monday, 'prefix': 'B', 'entity_type': 'DATE'}
# {'text': with, 'prefix': 'O', 'entity_type': ''}
# {'text': a, 'prefix': 'O', 'entity_type': ''}
# {'text': fintech, 'prefix': 'O', 'entity_type': ''}
# {'text': conference, 'prefix': 'O', 'entity_type': ''}
# {'text': and, 'prefix': 'O', 'entity_type': ''}
# {'text': conclude, 'prefix': 'O', 'entity_type': ''}
# {'text': this, 'prefix': 'B', 'entity_type': 'DATE'}
# {'text': weekend, 'prefix': 'I', 'entity_type': 'DATE'}
# {'text': with, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': return, 'prefix': 'O', 'entity_type': ''}
# {'text': of, 'prefix': 'O', 'entity_type': ''}
# {'text': a, 'prefix': 'O', 'entity_type': ''}
# {'text': major, 'prefix': 'O', 'entity_type': ''}
# {'text': international, 'prefix': 'O', 'entity_type': ''}
# {'text': sporting, 'prefix': 'O', 'entity_type': ''}
# {'text': event, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': Rugby, 'prefix': 'O', 'entity_type': ''}
# {'text': Sevens, 'prefix': 'B', 'entity_type': 'PERSON'}
# {'text': tournament, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': Iñaki, 'prefix': 'B', 'entity_type': 'PERSON'}
# {'text': Amate, 'prefix': 'I', 'entity_type': 'PERSON'}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': chairman, 'prefix': 'O', 'entity_type': ''}
# {'text': of, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'B', 'entity_type': 'ORG'}
# {'text': European, 'prefix': 'I', 'entity_type': 'ORG'}
# {'text': Chamber, 'prefix': 'I', 'entity_type': 'ORG'}
# {'text': of, 'prefix': 'I', 'entity_type': 'ORG'}
# {'text': Commerce, 'prefix': 'I', 'entity_type': 'ORG'}
# {'text': in, 'prefix': 'O', 'entity_type': ''}
# {'text': Hong, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': Kong, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': was, 'prefix': 'O', 'entity_type': ''}
# {'text': upbeat, 'prefix': 'O', 'entity_type': ''}
# {'text': about, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': event, 'prefix': 'O', 'entity_type': ''}
# {'text': and, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': pro, 'prefix': 'O', 'entity_type': ''}
# {'text': -, 'prefix': 'O', 'entity_type': ''}
# {'text': business, 'prefix': 'O', 'entity_type': ''}
# {'text': atmosphere, 'prefix': 'O', 'entity_type': ''}
# {'text': he, 'prefix': 'O', 'entity_type': ''}
# {'text': encountered, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text':  , 'prefix': 'O', 'entity_type': ''}
# {'text': “, 'prefix': 'O', 'entity_type': ''}
# {'text': I, 'prefix': 'O', 'entity_type': ''}
# {'text': have, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': say, 'prefix': 'O', 'entity_type': ''}
# {'text': how, 'prefix': 'O', 'entity_type': ''}
# {'text': positively, 'prefix': 'O', 'entity_type': ''}
# {'text': surprised, 'prefix': 'O', 'entity_type': ''}
# {'text': I, 'prefix': 'O', 'entity_type': ''}
# {'text': was, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': see, 'prefix': 'O', 'entity_type': ''}
# {'text': that, 'prefix': 'O', 'entity_type': ''}
# {'text': there, 'prefix': 'O', 'entity_type': ''}
# {'text': was, 'prefix': 'O', 'entity_type': ''}
# {'text': a, 'prefix': 'O', 'entity_type': ''}
# {'text': very, 'prefix': 'O', 'entity_type': ''}
# {'text': good, 'prefix': 'O', 'entity_type': ''}
# {'text': vibe, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': ”, 'prefix': 'O', 'entity_type': ''}
# {'text': Amate, 'prefix': 'B', 'entity_type': 'ORG'}
# {'text': said, 'prefix': 'O', 'entity_type': ''}
# {'text': Tuesday, 'prefix': 'B', 'entity_type': 'DATE'}
# {'text': as, 'prefix': 'O', 'entity_type': ''}
# {'text': he, 'prefix': 'O', 'entity_type': ''}
# {'text': headed, 'prefix': 'O', 'entity_type': ''}
# {'text': for, 'prefix': 'O', 'entity_type': ''}
# {'text': a, 'prefix': 'O', 'entity_type': ''}
# {'text': tour, 'prefix': 'O', 'entity_type': ''}
# {'text': and, 'prefix': 'O', 'entity_type': ''}
# {'text': welcome, 'prefix': 'O', 'entity_type': ''}
# {'text': dinner, 'prefix': 'O', 'entity_type': ''}
# {'text': at, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': M+, 'prefix': 'O', 'entity_type': ''}
# {'text': art, 'prefix': 'O', 'entity_type': ''}
# {'text': museum, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': “, 'prefix': 'O', 'entity_type': ''}
# {'text': It, 'prefix': 'O', 'entity_type': ''}
# {'text': felt, 'prefix': 'O', 'entity_type': ''}
# {'text': like, 'prefix': 'O', 'entity_type': ''}
# {'text': people, 'prefix': 'O', 'entity_type': ''}
# {'text': came, 'prefix': 'O', 'entity_type': ''}
# {'text': out, 'prefix': 'O', 'entity_type': ''}
# {'text': of, 'prefix': 'O', 'entity_type': ''}
# {'text': a, 'prefix': 'O', 'entity_type': ''}
# {'text': cave, 'prefix': 'O', 'entity_type': ''}
# {'text': with, 'prefix': 'O', 'entity_type': ''}
# {'text': a, 'prefix': 'O', 'entity_type': ''}
# {'text': lot, 'prefix': 'O', 'entity_type': ''}
# {'text': of, 'prefix': 'O', 'entity_type': ''}
# {'text': energy, 'prefix': 'O', 'entity_type': ''}
# {'text': and, 'prefix': 'O', 'entity_type': ''}
# {'text': willing, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': start, 'prefix': 'O', 'entity_type': ''}
# {'text': doing, 'prefix': 'O', 'entity_type': ''}
# {'text': business, 'prefix': 'O', 'entity_type': ''}
# {'text': again, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': ”The, 'prefix': 'O', 'entity_type': ''}
# {'text': summit, 'prefix': 'O', 'entity_type': ''}
# {'text': is, 'prefix': 'O', 'entity_type': ''}
# {'text': part, 'prefix': 'O', 'entity_type': ''}
# {'text': of, 'prefix': 'O', 'entity_type': ''}
# {'text': a, 'prefix': 'O', 'entity_type': ''}
# {'text': broader, 'prefix': 'O', 'entity_type': ''}
# {'text': campaign, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': draw, 'prefix': 'O', 'entity_type': ''}
# {'text': both, 'prefix': 'O', 'entity_type': ''}
# {'text': business, 'prefix': 'O', 'entity_type': ''}
# {'text': and, 'prefix': 'O', 'entity_type': ''}
# {'text': tourists, 'prefix': 'O', 'entity_type': ''}
# {'text': back, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': Hong, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': Kong, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': an, 'prefix': 'O', 'entity_type': ''}
# {'text': international, 'prefix': 'O', 'entity_type': ''}
# {'text': financial, 'prefix': 'O', 'entity_type': ''}
# {'text': center, 'prefix': 'O', 'entity_type': ''}
# {'text': of, 'prefix': 'O', 'entity_type': ''}
# {'text': 7.3, 'prefix': 'B', 'entity_type': 'CARDINAL'}
# {'text': million, 'prefix': 'I', 'entity_type': 'CARDINAL'}
# {'text': that, 'prefix': 'O', 'entity_type': ''}
# {'text': built, 'prefix': 'O', 'entity_type': ''}
# {'text': its, 'prefix': 'O', 'entity_type': ''}
# {'text': reputation, 'prefix': 'O', 'entity_type': ''}
# {'text': as, 'prefix': 'O', 'entity_type': ''}
# {'text': a, 'prefix': 'O', 'entity_type': ''}
# {'text': travel, 'prefix': 'O', 'entity_type': ''}
# {'text': hub, 'prefix': 'O', 'entity_type': ''}
# {'text': and, 'prefix': 'O', 'entity_type': ''}
# {'text': a, 'prefix': 'O', 'entity_type': ''}
# {'text': bastion, 'prefix': 'O', 'entity_type': ''}
# {'text': of, 'prefix': 'O', 'entity_type': ''}
# {'text': freedom, 'prefix': 'O', 'entity_type': ''}
# {'text': in, 'prefix': 'O', 'entity_type': ''}
# {'text': Asia, 'prefix': 'B', 'entity_type': 'LOC'}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': That, 'prefix': 'O', 'entity_type': ''}
# {'text': image, 'prefix': 'O', 'entity_type': ''}
# {'text': has, 'prefix': 'O', 'entity_type': ''}
# {'text': been, 'prefix': 'O', 'entity_type': ''}
# {'text': tarnished, 'prefix': 'O', 'entity_type': ''}
# {'text': by, 'prefix': 'O', 'entity_type': ''}
# {'text': strict, 'prefix': 'O', 'entity_type': ''}
# {'text': Covid, 'prefix': 'B', 'entity_type': 'PERSON'}
# {'text': restrictions, 'prefix': 'O', 'entity_type': ''}
# {'text': and, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': national, 'prefix': 'O', 'entity_type': ''}
# {'text': security, 'prefix': 'O', 'entity_type': ''}
# {'text': law, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': both, 'prefix': 'O', 'entity_type': ''}
# {'text': cited, 'prefix': 'O', 'entity_type': ''}
# {'text': as, 'prefix': 'O', 'entity_type': ''}
# {'text': reasons, 'prefix': 'O', 'entity_type': ''}
# {'text': for, 'prefix': 'O', 'entity_type': ''}
# {'text': leaving, 'prefix': 'O', 'entity_type': ''}
# {'text': in, 'prefix': 'O', 'entity_type': ''}
# {'text': a, 'prefix': 'O', 'entity_type': ''}
# {'text': mass, 'prefix': 'O', 'entity_type': ''}
# {'text': exodus, 'prefix': 'O', 'entity_type': ''}
# {'text': of, 'prefix': 'O', 'entity_type': ''}
# {'text':  , 'prefix': 'O', 'entity_type': ''}
# {'text': residents, 'prefix': 'O', 'entity_type': ''}
# {'text': and, 'prefix': 'O', 'entity_type': ''}
# {'text': expatriates, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text':  , 'prefix': 'O', 'entity_type': ''}
# {'text': Chinese, 'prefix': 'B', 'entity_type': 'NORP'}
# {'text': president, 'prefix': 'O', 'entity_type': ''}
# {'text': visits, 'prefix': 'O', 'entity_type': ''}
# {'text': Hong, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': Kong, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': 25, 'prefix': 'B', 'entity_type': 'DATE'}
# {'text': years, 'prefix': 'I', 'entity_type': 'DATE'}
# {'text': after, 'prefix': 'O', 'entity_type': ''}
# {'text': Britain, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': rule, 'prefix': 'O', 'entity_type': ''}
# {'text': ends, 'prefix': 'O', 'entity_type': ''}
# {'text': July, 'prefix': 'B', 'entity_type': 'DATE'}
# {'text': 2, 'prefix': 'I', 'entity_type': 'DATE'}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': 202202:37Despite, 'prefix': 'O', 'entity_type': ''}
# {'text': official, 'prefix': 'O', 'entity_type': ''}
# {'text': efforts, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': not, 'prefix': 'O', 'entity_type': ''}
# {'text': many, 'prefix': 'O', 'entity_type': ''}
# {'text': people, 'prefix': 'O', 'entity_type': ''}
# {'text': are, 'prefix': 'O', 'entity_type': ''}
# {'text': coming, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': replace, 'prefix': 'O', 'entity_type': ''}
# {'text': those, 'prefix': 'O', 'entity_type': ''}
# {'text': who, 'prefix': 'O', 'entity_type': ''}
# {'text': have, 'prefix': 'O', 'entity_type': ''}
# {'text': left, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': According, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': government, 'prefix': 'O', 'entity_type': ''}
# {'text': statistics, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': about, 'prefix': 'B', 'entity_type': 'CARDINAL'}
# {'text': 319,000, 'prefix': 'I', 'entity_type': 'CARDINAL'}
# {'text': people, 'prefix': 'O', 'entity_type': ''}
# {'text': arrived, 'prefix': 'O', 'entity_type': ''}
# {'text': in, 'prefix': 'O', 'entity_type': ''}
# {'text': Hong, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': Kong, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': last, 'prefix': 'B', 'entity_type': 'DATE'}
# {'text': month, 'prefix': 'I', 'entity_type': 'DATE'}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': down, 'prefix': 'O', 'entity_type': ''}
# {'text': 97, 'prefix': 'B', 'entity_type': 'PERCENT'}
# {'text': %, 'prefix': 'I', 'entity_type': 'PERCENT'}
# {'text': from, 'prefix': 'O', 'entity_type': ''}
# {'text': 10.8, 'prefix': 'B', 'entity_type': 'CARDINAL'}
# {'text': million, 'prefix': 'I', 'entity_type': 'CARDINAL'}
# {'text': in, 'prefix': 'O', 'entity_type': ''}
# {'text': October, 'prefix': 'B', 'entity_type': 'DATE'}
# {'text': 2019, 'prefix': 'I', 'entity_type': 'DATE'}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': Companies, 'prefix': 'O', 'entity_type': ''}
# {'text': have, 'prefix': 'O', 'entity_type': ''}
# {'text': reported, 'prefix': 'O', 'entity_type': ''}
# {'text': difficulties, 'prefix': 'O', 'entity_type': ''}
# {'text': recruiting, 'prefix': 'O', 'entity_type': ''}
# {'text': and, 'prefix': 'O', 'entity_type': ''}
# {'text': retaining, 'prefix': 'O', 'entity_type': ''}
# {'text': talent, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': And, 'prefix': 'O', 'entity_type': ''}
# {'text': even, 'prefix': 'O', 'entity_type': ''}
# {'text': as, 'prefix': 'O', 'entity_type': ''}
# {'text': Hong, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': Kong, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': eases, 'prefix': 'O', 'entity_type': ''}
# {'text': Covid, 'prefix': 'B', 'entity_type': 'PERSON'}
# {'text': restrictions, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': bad, 'prefix': 'O', 'entity_type': ''}
# {'text': news, 'prefix': 'O', 'entity_type': ''}
# {'text': keeps, 'prefix': 'O', 'entity_type': ''}
# {'text': coming, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': The, 'prefix': 'O', 'entity_type': ''}
# {'text': economy, 'prefix': 'O', 'entity_type': ''}
# {'text': shrank, 'prefix': 'O', 'entity_type': ''}
# {'text': 4.5, 'prefix': 'B', 'entity_type': 'PERCENT'}
# {'text': %, 'prefix': 'I', 'entity_type': 'PERCENT'}
# {'text': in, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'B', 'entity_type': 'DATE'}
# {'text': third, 'prefix': 'I', 'entity_type': 'DATE'}
# {'text': quarter, 'prefix': 'I', 'entity_type': 'DATE'}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': extending, 'prefix': 'O', 'entity_type': ''}
# {'text': a, 'prefix': 'O', 'entity_type': ''}
# {'text': recession, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': Airlines, 'prefix': 'O', 'entity_type': ''}
# {'text': are, 'prefix': 'O', 'entity_type': ''}
# {'text': pulling, 'prefix': 'O', 'entity_type': ''}
# {'text': out, 'prefix': 'O', 'entity_type': ''}
# {'text': of, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': city, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': once, 'prefix': 'O', 'entity_type': ''}
# {'text': a, 'prefix': 'O', 'entity_type': ''}
# {'text': global, 'prefix': 'O', 'entity_type': ''}
# {'text': aviation, 'prefix': 'O', 'entity_type': ''}
# {'text': hub, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': According, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': one, 'prefix': 'B', 'entity_type': 'CARDINAL'}
# {'text': report, 'prefix': 'O', 'entity_type': ''}
# {'text': last, 'prefix': 'B', 'entity_type': 'DATE'}
# {'text': month, 'prefix': 'I', 'entity_type': 'DATE'}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': Hong, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': Kong, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': has, 'prefix': 'O', 'entity_type': ''}
# {'text': lost, 'prefix': 'O', 'entity_type': ''}
# {'text': its, 'prefix': 'O', 'entity_type': ''}
# {'text': status, 'prefix': 'O', 'entity_type': ''}
# {'text': as, 'prefix': 'O', 'entity_type': ''}
# {'text': Asia, 'prefix': 'B', 'entity_type': 'LOC'}
# {'text': ’s, 'prefix': 'O', 'entity_type': ''}
# {'text': top, 'prefix': 'O', 'entity_type': ''}
# {'text': financial, 'prefix': 'O', 'entity_type': ''}
# {'text': center, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': Singapore, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': There, 'prefix': 'O', 'entity_type': ''}
# {'text': are, 'prefix': 'O', 'entity_type': ''}
# {'text': also, 'prefix': 'O', 'entity_type': ''}
# {'text': daily, 'prefix': 'B', 'entity_type': 'DATE'}
# {'text': court, 'prefix': 'O', 'entity_type': ''}
# {'text': developments, 'prefix': 'O', 'entity_type': ''}
# {'text': stemming, 'prefix': 'O', 'entity_type': ''}
# {'text': from, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': 2019, 'prefix': 'B', 'entity_type': 'DATE'}
# {'text': anti, 'prefix': 'O', 'entity_type': ''}
# {'text': -, 'prefix': 'O', 'entity_type': ''}
# {'text': government, 'prefix': 'O', 'entity_type': ''}
# {'text': protests, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': in, 'prefix': 'O', 'entity_type': ''}
# {'text': which, 'prefix': 'O', 'entity_type': ''}
# {'text': more, 'prefix': 'B', 'entity_type': 'CARDINAL'}
# {'text': than, 'prefix': 'I', 'entity_type': 'CARDINAL'}
# {'text': 10,000, 'prefix': 'I', 'entity_type': 'CARDINAL'}
# {'text': people, 'prefix': 'O', 'entity_type': ''}
# {'text': have, 'prefix': 'O', 'entity_type': ''}
# {'text': been, 'prefix': 'O', 'entity_type': ''}
# {'text': arrested, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': In, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'B', 'entity_type': 'DATE'}
# {'text': last, 'prefix': 'I', 'entity_type': 'DATE'}
# {'text': two, 'prefix': 'I', 'entity_type': 'DATE'}
# {'text': months, 'prefix': 'I', 'entity_type': 'DATE'}
# {'text': alone, 'prefix': 'I', 'entity_type': 'DATE'}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': Hong, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': Kong, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': has, 'prefix': 'O', 'entity_type': ''}
# {'text': put, 'prefix': 'O', 'entity_type': ''}
# {'text': a, 'prefix': 'O', 'entity_type': ''}
# {'text': 90, 'prefix': 'B', 'entity_type': 'DATE'}
# {'text': -, 'prefix': 'I', 'entity_type': 'DATE'}
# {'text': year, 'prefix': 'I', 'entity_type': 'DATE'}
# {'text': -, 'prefix': 'I', 'entity_type': 'DATE'}
# {'text': old, 'prefix': 'I', 'entity_type': 'DATE'}
# {'text': Roman, 'prefix': 'B', 'entity_type': 'NORP'}
# {'text': Catholic, 'prefix': 'I', 'entity_type': 'NORP'}
# {'text': cleric, 'prefix': 'O', 'entity_type': ''}
# {'text': on, 'prefix': 'O', 'entity_type': ''}
# {'text': trial, 'prefix': 'O', 'entity_type': ''}
# {'text': over, 'prefix': 'O', 'entity_type': ''}
# {'text': a, 'prefix': 'O', 'entity_type': ''}
# {'text': legal, 'prefix': 'O', 'entity_type': ''}
# {'text': aid, 'prefix': 'O', 'entity_type': ''}
# {'text': fund, 'prefix': 'O', 'entity_type': ''}
# {'text': for, 'prefix': 'O', 'entity_type': ''}
# {'text': protesters, 'prefix': 'O', 'entity_type': ''}
# {'text': ;, 'prefix': 'O', 'entity_type': ''}
# {'text': jailed, 'prefix': 'O', 'entity_type': ''}
# {'text': five, 'prefix': 'B', 'entity_type': 'CARDINAL'}
# {'text': speech, 'prefix': 'O', 'entity_type': ''}
# {'text': therapists, 'prefix': 'O', 'entity_type': ''}
# {'text': over, 'prefix': 'O', 'entity_type': ''}
# {'text': “, 'prefix': 'O', 'entity_type': ''}
# {'text': seditious, 'prefix': 'O', 'entity_type': ''}
# {'text': ”, 'prefix': 'O', 'entity_type': ''}
# {'text': children, 'prefix': 'O', 'entity_type': ''}
# {'text': ’s, 'prefix': 'O', 'entity_type': ''}
# {'text': books, 'prefix': 'O', 'entity_type': ''}
# {'text': ;, 'prefix': 'O', 'entity_type': ''}
# {'text': jailed, 'prefix': 'O', 'entity_type': ''}
# {'text': two, 'prefix': 'B', 'entity_type': 'CARDINAL'}
# {'text': people, 'prefix': 'O', 'entity_type': ''}
# {'text': for, 'prefix': 'O', 'entity_type': ''}
# {'text': sedition, 'prefix': 'O', 'entity_type': ''}
# {'text': after, 'prefix': 'O', 'entity_type': ''}
# {'text': they, 'prefix': 'O', 'entity_type': ''}
# {'text': clapped, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': support, 'prefix': 'O', 'entity_type': ''}
# {'text': defendants, 'prefix': 'O', 'entity_type': ''}
# {'text': in, 'prefix': 'O', 'entity_type': ''}
# {'text': court, 'prefix': 'O', 'entity_type': ''}
# {'text': ;, 'prefix': 'O', 'entity_type': ''}
# {'text': and, 'prefix': 'O', 'entity_type': ''}
# {'text': convicted, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': democracy, 'prefix': 'O', 'entity_type': ''}
# {'text': activist, 'prefix': 'O', 'entity_type': ''}
# {'text': Jimmy, 'prefix': 'B', 'entity_type': 'PERSON'}
# {'text': Lai, 'prefix': 'I', 'entity_type': 'PERSON'}
# {'text': on, 'prefix': 'O', 'entity_type': ''}
# {'text': fraud, 'prefix': 'O', 'entity_type': ''}
# {'text': charges, 'prefix': 'O', 'entity_type': ''}
# {'text': that, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': United, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': States, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': condemned, 'prefix': 'O', 'entity_type': ''}
# {'text': as, 'prefix': 'O', 'entity_type': ''}
# {'text': “, 'prefix': 'O', 'entity_type': ''}
# {'text': spurious, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': ”, 'prefix': 'O', 'entity_type': ''}
# {'text':  , 'prefix': 'O', 'entity_type': ''}
# {'text': Hong, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': Kong, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': media, 'prefix': 'O', 'entity_type': ''}
# {'text': tycoon, 'prefix': 'O', 'entity_type': ''}
# {'text': and, 'prefix': 'O', 'entity_type': ''}
# {'text': democracy, 'prefix': 'O', 'entity_type': ''}
# {'text': activist, 'prefix': 'O', 'entity_type': ''}
# {'text': Jimmy, 'prefix': 'B', 'entity_type': 'PERSON'}
# {'text': Lai, 'prefix': 'I', 'entity_type': 'PERSON'}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': 75, 'prefix': 'B', 'entity_type': 'DATE'}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': was, 'prefix': 'O', 'entity_type': ''}
# {'text': convicted, 'prefix': 'O', 'entity_type': ''}
# {'text': last, 'prefix': 'B', 'entity_type': 'DATE'}
# {'text': month, 'prefix': 'I', 'entity_type': 'DATE'}
# {'text': on, 'prefix': 'O', 'entity_type': ''}
# {'text': fraud, 'prefix': 'O', 'entity_type': ''}
# {'text': charges, 'prefix': 'O', 'entity_type': ''}
# {'text': that, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': United, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': States, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': called, 'prefix': 'O', 'entity_type': ''}
# {'text': “, 'prefix': 'O', 'entity_type': ''}
# {'text': spurious, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': ”Anthony, 'prefix': 'O', 'entity_type': ''}
# {'text': Wallace, 'prefix': 'B', 'entity_type': 'PERSON'}
# {'text':  , 'prefix': 'O', 'entity_type': ''}
# {'text': /, 'prefix': 'O', 'entity_type': ''}
# {'text': AFP, 'prefix': 'O', 'entity_type': ''}
# {'text': -, 'prefix': 'O', 'entity_type': ''}
# {'text': Getty, 'prefix': 'O', 'entity_type': ''}
# {'text': Images, 'prefix': 'O', 'entity_type': ''}
# {'text': fileMore, 'prefix': 'O', 'entity_type': ''}
# {'text': than, 'prefix': 'O', 'entity_type': ''}
# {'text': 200, 'prefix': 'B', 'entity_type': 'CARDINAL'}
# {'text': people, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': including, 'prefix': 'O', 'entity_type': ''}
# {'text': Lai, 'prefix': 'B', 'entity_type': 'PERSON'}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': have, 'prefix': 'O', 'entity_type': ''}
# {'text': also, 'prefix': 'O', 'entity_type': ''}
# {'text': been, 'prefix': 'O', 'entity_type': ''}
# {'text': arrested, 'prefix': 'O', 'entity_type': ''}
# {'text': under, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': national, 'prefix': 'O', 'entity_type': ''}
# {'text': security, 'prefix': 'O', 'entity_type': ''}
# {'text': law, 'prefix': 'O', 'entity_type': ''}
# {'text': that, 'prefix': 'O', 'entity_type': ''}
# {'text': Beijing, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': imposed, 'prefix': 'O', 'entity_type': ''}
# {'text': in, 'prefix': 'O', 'entity_type': ''}
# {'text': 2020, 'prefix': 'B', 'entity_type': 'DATE'}
# {'text': in, 'prefix': 'O', 'entity_type': ''}
# {'text': response, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': protests, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': The, 'prefix': 'O', 'entity_type': ''}
# {'text': U.S., 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': has, 'prefix': 'O', 'entity_type': ''}
# {'text': spoken, 'prefix': 'O', 'entity_type': ''}
# {'text': out, 'prefix': 'O', 'entity_type': ''}
# {'text': repeatedly, 'prefix': 'O', 'entity_type': ''}
# {'text': against, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': law, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': which, 'prefix': 'O', 'entity_type': ''}
# {'text': criminalized, 'prefix': 'O', 'entity_type': ''}
# {'text': subversion, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': secession, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': terrorism, 'prefix': 'O', 'entity_type': ''}
# {'text': and, 'prefix': 'O', 'entity_type': ''}
# {'text': collusion, 'prefix': 'O', 'entity_type': ''}
# {'text': with, 'prefix': 'O', 'entity_type': ''}
# {'text': foreign, 'prefix': 'O', 'entity_type': ''}
# {'text': forces, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': Hong, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': Kong, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': and, 'prefix': 'O', 'entity_type': ''}
# {'text': Chinese, 'prefix': 'B', 'entity_type': 'NORP'}
# {'text': officials, 'prefix': 'O', 'entity_type': ''}
# {'text': say, 'prefix': 'O', 'entity_type': ''}
# {'text': it, 'prefix': 'O', 'entity_type': ''}
# {'text': was, 'prefix': 'O', 'entity_type': ''}
# {'text': necessary, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': restore, 'prefix': 'O', 'entity_type': ''}
# {'text': stability, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': While, 'prefix': 'O', 'entity_type': ''}
# {'text': it, 'prefix': 'O', 'entity_type': ''}
# {'text': may, 'prefix': 'O', 'entity_type': ''}
# {'text': not, 'prefix': 'O', 'entity_type': ''}
# {'text': be, 'prefix': 'O', 'entity_type': ''}
# {'text': realistic, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': expect, 'prefix': 'O', 'entity_type': ''}
# {'text': businesses, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': turn, 'prefix': 'O', 'entity_type': ''}
# {'text': away, 'prefix': 'O', 'entity_type': ''}
# {'text': from, 'prefix': 'O', 'entity_type': ''}
# {'text': China, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': ’s, 'prefix': 'O', 'entity_type': ''}
# {'text': huge, 'prefix': 'O', 'entity_type': ''}
# {'text': market, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': global, 'prefix': 'O', 'entity_type': ''}
# {'text': business, 'prefix': 'O', 'entity_type': ''}
# {'text': leaders, 'prefix': 'O', 'entity_type': ''}
# {'text': “, 'prefix': 'O', 'entity_type': ''}
# {'text': need, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': recognize, 'prefix': 'O', 'entity_type': ''}
# {'text': that, 'prefix': 'O', 'entity_type': ''}
# {'text': there, 'prefix': 'O', 'entity_type': ''}
# {'text': ’s, 'prefix': 'O', 'entity_type': ''}
# {'text': a, 'prefix': 'O', 'entity_type': ''}
# {'text': new, 'prefix': 'O', 'entity_type': ''}
# {'text': situation, 'prefix': 'O', 'entity_type': ''}
# {'text': in, 'prefix': 'O', 'entity_type': ''}
# {'text': Hong, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': Kong, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': there, 'prefix': 'O', 'entity_type': ''}
# {'text': ’s, 'prefix': 'O', 'entity_type': ''}
# {'text': a, 'prefix': 'O', 'entity_type': ''}
# {'text': new, 'prefix': 'O', 'entity_type': ''}
# {'text': reality, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': ”, 'prefix': 'O', 'entity_type': ''}
# {'text': said, 'prefix': 'O', 'entity_type': ''}
# {'text': Brian, 'prefix': 'B', 'entity_type': 'PERSON'}
# {'text': Kern, 'prefix': 'I', 'entity_type': 'PERSON'}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': lead, 'prefix': 'O', 'entity_type': ''}
# {'text': researcher, 'prefix': 'O', 'entity_type': ''}
# {'text': for, 'prefix': 'O', 'entity_type': ''}
# {'text': a, 'prefix': 'O', 'entity_type': ''}
# {'text': report, 'prefix': 'O', 'entity_type': ''}
# {'text': on, 'prefix': 'O', 'entity_type': ''}
# {'text': doing, 'prefix': 'O', 'entity_type': ''}
# {'text': business, 'prefix': 'O', 'entity_type': ''}
# {'text': in, 'prefix': 'O', 'entity_type': ''}
# {'text': Hong, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': Kong, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': that, 'prefix': 'O', 'entity_type': ''}
# {'text': was, 'prefix': 'O', 'entity_type': ''}
# {'text': published, 'prefix': 'O', 'entity_type': ''}
# {'text': last, 'prefix': 'B', 'entity_type': 'DATE'}
# {'text': month, 'prefix': 'I', 'entity_type': 'DATE'}
# {'text': by, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'B', 'entity_type': 'ORG'}
# {'text': Hong, 'prefix': 'I', 'entity_type': 'ORG'}
# {'text': Kong, 'prefix': 'I', 'entity_type': 'ORG'}
# {'text': Democracy, 'prefix': 'I', 'entity_type': 'ORG'}
# {'text': Council, 'prefix': 'I', 'entity_type': 'ORG'}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': a, 'prefix': 'O', 'entity_type': ''}
# {'text': nonprofit, 'prefix': 'O', 'entity_type': ''}
# {'text': group, 'prefix': 'O', 'entity_type': ''}
# {'text': based, 'prefix': 'O', 'entity_type': ''}
# {'text': in, 'prefix': 'O', 'entity_type': ''}
# {'text': Washington, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text':  , 'prefix': 'O', 'entity_type': ''}
# {'text': The, 'prefix': 'O', 'entity_type': ''}
# {'text': group, 'prefix': 'O', 'entity_type': ''}
# {'text': ’s, 'prefix': 'O', 'entity_type': ''}
# {'text': website, 'prefix': 'O', 'entity_type': ''}
# {'text': appears, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': have, 'prefix': 'O', 'entity_type': ''}
# {'text': been, 'prefix': 'O', 'entity_type': ''}
# {'text': blocked, 'prefix': 'O', 'entity_type': ''}
# {'text': in, 'prefix': 'O', 'entity_type': ''}
# {'text': Hong, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': Kong, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': since, 'prefix': 'O', 'entity_type': ''}
# {'text': shortly, 'prefix': 'O', 'entity_type': ''}
# {'text': after, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': report, 'prefix': 'O', 'entity_type': ''}
# {'text': ’s, 'prefix': 'O', 'entity_type': ''}
# {'text': release, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': Businesses, 'prefix': 'O', 'entity_type': ''}
# {'text': “, 'prefix': 'O', 'entity_type': ''}
# {'text': need, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': develop, 'prefix': 'O', 'entity_type': ''}
# {'text': policies, 'prefix': 'O', 'entity_type': ''}
# {'text': and, 'prefix': 'O', 'entity_type': ''}
# {'text': guidelines, 'prefix': 'O', 'entity_type': ''}
# {'text': and, 'prefix': 'O', 'entity_type': ''}
# {'text': due, 'prefix': 'O', 'entity_type': ''}
# {'text': diligence, 'prefix': 'O', 'entity_type': ''}
# {'text': processes, 'prefix': 'O', 'entity_type': ''}
# {'text': so, 'prefix': 'O', 'entity_type': ''}
# {'text': as, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': guard, 'prefix': 'O', 'entity_type': ''}
# {'text': against, 'prefix': 'O', 'entity_type': ''}
# {'text': perhaps, 'prefix': 'O', 'entity_type': ''}
# {'text': inadvertently, 'prefix': 'O', 'entity_type': ''}
# {'text': doing, 'prefix': 'O', 'entity_type': ''}
# {'text': things, 'prefix': 'O', 'entity_type': ''}
# {'text': that, 'prefix': 'O', 'entity_type': ''}
# {'text': are, 'prefix': 'O', 'entity_type': ''}
# {'text': against, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': U.N., 'prefix': 'B', 'entity_type': 'ORG'}
# {'text': principles, 'prefix': 'O', 'entity_type': ''}
# {'text': on, 'prefix': 'O', 'entity_type': ''}
# {'text': business, 'prefix': 'O', 'entity_type': ''}
# {'text': and, 'prefix': 'O', 'entity_type': ''}
# {'text': human, 'prefix': 'O', 'entity_type': ''}
# {'text': rights, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': ”, 'prefix': 'O', 'entity_type': ''}
# {'text': Kern, 'prefix': 'B', 'entity_type': 'PERSON'}
# {'text': said, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text':  , 'prefix': 'O', 'entity_type': ''}
# {'text': Police, 'prefix': 'O', 'entity_type': ''}
# {'text': were, 'prefix': 'O', 'entity_type': ''}
# {'text': out, 'prefix': 'O', 'entity_type': ''}
# {'text': in, 'prefix': 'O', 'entity_type': ''}
# {'text': Hong, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': Kong, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': on, 'prefix': 'O', 'entity_type': ''}
# {'text': June, 'prefix': 'B', 'entity_type': 'DATE'}
# {'text': 4, 'prefix': 'I', 'entity_type': 'DATE'}
# {'text': ,, 'prefix': 'I', 'entity_type': 'DATE'}
# {'text': 2021, 'prefix': 'I', 'entity_type': 'DATE'}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': prevent, 'prefix': 'O', 'entity_type': ''}
# {'text': an, 'prefix': 'O', 'entity_type': ''}
# {'text': annual, 'prefix': 'B', 'entity_type': 'DATE'}
# {'text': vigil, 'prefix': 'O', 'entity_type': ''}
# {'text': for, 'prefix': 'O', 'entity_type': ''}
# {'text': victims, 'prefix': 'O', 'entity_type': ''}
# {'text': of, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': Tiananmen, 'prefix': 'B', 'entity_type': 'FAC'}
# {'text': Square, 'prefix': 'I', 'entity_type': 'FAC'}
# {'text': massacre, 'prefix': 'O', 'entity_type': ''}
# {'text': in, 'prefix': 'O', 'entity_type': ''}
# {'text': Beijing, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': Paul, 'prefix': 'B', 'entity_type': 'PERSON'}
# {'text': Yeung, 'prefix': 'I', 'entity_type': 'PERSON'}
# ...
# {'text': interference, 'prefix': 'O', 'entity_type': ''}
# {'text': from, 'prefix': 'O', 'entity_type': ''}
# {'text': China, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': ”Outside, 'prefix': 'O', 'entity_type': ''}
# {'text': a, 'prefix': 'O', 'entity_type': ''}
# {'text': closed, 'prefix': 'O', 'entity_type': ''}
# {'text': -, 'prefix': 'O', 'entity_type': ''}
# {'text': down, 'prefix': 'O', 'entity_type': ''}
# {'text': business, 'prefix': 'O', 'entity_type': ''}
# {'text': in, 'prefix': 'O', 'entity_type': ''}
# {'text': Hong, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': Kong, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': on, 'prefix': 'O', 'entity_type': ''}
# {'text': Tuesday, 'prefix': 'B', 'entity_type': 'DATE'}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': Peter, 'prefix': 'B', 'entity_type': 'PERSON'}
# {'text': Parks, 'prefix': 'I', 'entity_type': 'PERSON'}
# {'text': /, 'prefix': 'O', 'entity_type': ''}
# {'text': AFP, 'prefix': 'O', 'entity_type': ''}
# {'text': -, 'prefix': 'O', 'entity_type': ''}
# {'text': Getty, 'prefix': 'O', 'entity_type': ''}
# {'text': ImagesLingering, 'prefix': 'O', 'entity_type': ''}
# {'text': Covid, 'prefix': 'O', 'entity_type': ''}
# {'text': restrictionsWhile, 'prefix': 'O', 'entity_type': ''}
# {'text': keeping, 'prefix': 'O', 'entity_type': ''}
# {'text': relatively, 'prefix': 'O', 'entity_type': ''}
# {'text': quiet, 'prefix': 'O', 'entity_type': ''}
# {'text': on, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': national, 'prefix': 'O', 'entity_type': ''}
# {'text': security, 'prefix': 'O', 'entity_type': ''}
# {'text': law, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': businesses, 'prefix': 'O', 'entity_type': ''}
# {'text': have, 'prefix': 'O', 'entity_type': ''}
# {'text': been, 'prefix': 'O', 'entity_type': ''}
# {'text': much, 'prefix': 'O', 'entity_type': ''}
# {'text': more, 'prefix': 'O', 'entity_type': ''}
# {'text': vocal, 'prefix': 'O', 'entity_type': ''}
# {'text': about, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': Covid, 'prefix': 'B', 'entity_type': 'NORP'}
# {'text': restrictions, 'prefix': 'O', 'entity_type': ''}
# {'text': and, 'prefix': 'O', 'entity_type': ''}
# {'text': given, 'prefix': 'O', 'entity_type': ''}
# {'text': Lee, 'prefix': 'B', 'entity_type': 'PERSON'}
# {'text': credit, 'prefix': 'O', 'entity_type': ''}
# {'text': for, 'prefix': 'O', 'entity_type': ''}
# {'text': easing, 'prefix': 'O', 'entity_type': ''}
# {'text': them, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': Many, 'prefix': 'O', 'entity_type': ''}
# {'text': in, 'prefix': 'O', 'entity_type': ''}
# {'text': Hong, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': Kong, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': breathed, 'prefix': 'O', 'entity_type': ''}
# {'text': a, 'prefix': 'O', 'entity_type': ''}
# {'text': sigh, 'prefix': 'O', 'entity_type': ''}
# {'text': of, 'prefix': 'O', 'entity_type': ''}
# {'text': relief, 'prefix': 'O', 'entity_type': ''}
# {'text': in, 'prefix': 'O', 'entity_type': ''}
# {'text': September, 'prefix': 'B', 'entity_type': 'DATE'}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': when, 'prefix': 'O', 'entity_type': ''}
# {'text': Lee, 'prefix': 'B', 'entity_type': 'PERSON'}
# {'text': announced, 'prefix': 'O', 'entity_type': ''}
# {'text': an, 'prefix': 'O', 'entity_type': ''}
# {'text': end, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': mandatory, 'prefix': 'O', 'entity_type': ''}
# {'text': hotel, 'prefix': 'O', 'entity_type': ''}
# {'text': quarantine, 'prefix': 'O', 'entity_type': ''}
# {'text': for, 'prefix': 'O', 'entity_type': ''}
# {'text': overseas, 'prefix': 'O', 'entity_type': ''}
# {'text': arrivals, 'prefix': 'O', 'entity_type': ''}
# {'text': that, 'prefix': 'O', 'entity_type': ''}
# {'text': at, 'prefix': 'O', 'entity_type': ''}
# {'text': one, 'prefix': 'B', 'entity_type': 'CARDINAL'}
# {'text': point, 'prefix': 'O', 'entity_type': ''}
# {'text': extended, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': 21, 'prefix': 'B', 'entity_type': 'DATE'}
# {'text': days, 'prefix': 'I', 'entity_type': 'DATE'}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text':  , 'prefix': 'O', 'entity_type': ''}
# {'text': “, 'prefix': 'O', 'entity_type': ''}
# {'text': We, 'prefix': 'O', 'entity_type': ''}
# {'text': ’re, 'prefix': 'O', 'entity_type': ''}
# {'text': starting, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': see, 'prefix': 'O', 'entity_type': ''}
# {'text': more, 'prefix': 'O', 'entity_type': ''}
# {'text': common, 'prefix': 'O', 'entity_type': ''}
# {'text': sense, 'prefix': 'O', 'entity_type': ''}
# {'text': ”, 'prefix': 'O', 'entity_type': ''}
# {'text': in, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': way, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': government, 'prefix': 'O', 'entity_type': ''}
# {'text': balances, 'prefix': 'O', 'entity_type': ''}
# {'text': Covid, 'prefix': 'B', 'entity_type': 'PERSON'}
# {'text': prevention, 'prefix': 'O', 'entity_type': ''}
# {'text': with, 'prefix': 'O', 'entity_type': ''}
# {'text': economic, 'prefix': 'O', 'entity_type': ''}
# {'text': concerns, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': Amate, 'prefix': 'B', 'entity_type': 'ORG'}
# {'text': said, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': But, 'prefix': 'O', 'entity_type': ''}
# {'text': other, 'prefix': 'O', 'entity_type': ''}
# {'text': restrictions, 'prefix': 'O', 'entity_type': ''}
# {'text': linger, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': including, 'prefix': 'O', 'entity_type': ''}
# {'text': a, 'prefix': 'O', 'entity_type': ''}
# {'text': vaccine, 'prefix': 'O', 'entity_type': ''}
# {'text': pass, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': enter, 'prefix': 'O', 'entity_type': ''}
# {'text': bars, 'prefix': 'O', 'entity_type': ''}
# {'text': and, 'prefix': 'O', 'entity_type': ''}
# {'text': restaurants, 'prefix': 'O', 'entity_type': ''}
# {'text': and, 'prefix': 'O', 'entity_type': ''}
# {'text': compulsory, 'prefix': 'O', 'entity_type': ''}
# {'text': mask, 'prefix': 'O', 'entity_type': ''}
# {'text': wearing, 'prefix': 'O', 'entity_type': ''}
# {'text': even, 'prefix': 'O', 'entity_type': ''}
# {'text': outdoors, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': Though, 'prefix': 'O', 'entity_type': ''}
# {'text': overseas, 'prefix': 'O', 'entity_type': ''}
# {'text': arrivals, 'prefix': 'O', 'entity_type': ''}
# {'text': no, 'prefix': 'O', 'entity_type': ''}
# {'text': longer, 'prefix': 'O', 'entity_type': ''}
# {'text': have, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': quarantine, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': they, 'prefix': 'O', 'entity_type': ''}
# {'text': are, 'prefix': 'O', 'entity_type': ''}
# {'text': prohibited, 'prefix': 'O', 'entity_type': ''}
# {'text': from, 'prefix': 'O', 'entity_type': ''}
# {'text': visiting, 'prefix': 'O', 'entity_type': ''}
# {'text': bars, 'prefix': 'O', 'entity_type': ''}
# {'text': and, 'prefix': 'O', 'entity_type': ''}
# {'text': restaurants, 'prefix': 'O', 'entity_type': ''}
# {'text': for, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'B', 'entity_type': 'DATE'}
# {'text': first, 'prefix': 'I', 'entity_type': 'DATE'}
# {'text': three, 'prefix': 'I', 'entity_type': 'DATE'}
# {'text': days, 'prefix': 'I', 'entity_type': 'DATE'}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': and, 'prefix': 'O', 'entity_type': ''}
# {'text': those, 'prefix': 'O', 'entity_type': ''}
# {'text': who, 'prefix': 'O', 'entity_type': ''}
# {'text': test, 'prefix': 'O', 'entity_type': ''}
# {'text': positive, 'prefix': 'O', 'entity_type': ''}
# {'text': for, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': virus, 'prefix': 'O', 'entity_type': ''}
# {'text': may, 'prefix': 'O', 'entity_type': ''}
# {'text': still, 'prefix': 'O', 'entity_type': ''}
# {'text': be, 'prefix': 'O', 'entity_type': ''}
# {'text': sent, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': government, 'prefix': 'O', 'entity_type': ''}
# {'text': quarantine, 'prefix': 'O', 'entity_type': ''}
# {'text': facilities, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text':  , 'prefix': 'O', 'entity_type': ''}
# {'text': Officials, 'prefix': 'O', 'entity_type': ''}
# {'text': have, 'prefix': 'O', 'entity_type': ''}
# {'text': relaxed, 'prefix': 'O', 'entity_type': ''}
# {'text': some, 'prefix': 'O', 'entity_type': ''}
# {'text': of, 'prefix': 'O', 'entity_type': ''}
# {'text': these, 'prefix': 'O', 'entity_type': ''}
# {'text': rules, 'prefix': 'O', 'entity_type': ''}
# {'text': for, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': summit, 'prefix': 'O', 'entity_type': ''}
# {'text': attendees, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': allowing, 'prefix': 'O', 'entity_type': ''}
# {'text': them, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': visit, 'prefix': 'O', 'entity_type': ''}
# {'text': private, 'prefix': 'O', 'entity_type': ''}
# {'text': dining, 'prefix': 'O', 'entity_type': ''}
# {'text': rooms, 'prefix': 'O', 'entity_type': ''}
# {'text': and, 'prefix': 'O', 'entity_type': ''}
# {'text': leave, 'prefix': 'O', 'entity_type': ''}
# {'text': immediately, 'prefix': 'O', 'entity_type': ''}
# {'text': on, 'prefix': 'O', 'entity_type': ''}
# {'text': their, 'prefix': 'O', 'entity_type': ''}
# {'text': own, 'prefix': 'O', 'entity_type': ''}
# {'text': private, 'prefix': 'O', 'entity_type': ''}
# {'text': jets, 'prefix': 'O', 'entity_type': ''}
# {'text': if, 'prefix': 'O', 'entity_type': ''}
# {'text': they, 'prefix': 'O', 'entity_type': ''}
# {'text': test, 'prefix': 'O', 'entity_type': ''}
# {'text': positive, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': Hong, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': Kong, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': ’s, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': financial, 'prefix': 'O', 'entity_type': ''}
# {'text': secretary, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': Paul, 'prefix': 'B', 'entity_type': 'PERSON'}
# {'text': Chan, 'prefix': 'I', 'entity_type': 'PERSON'}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': was, 'prefix': 'O', 'entity_type': ''}
# {'text': allowed, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': attend, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': summit, 'prefix': 'O', 'entity_type': ''}
# {'text': this, 'prefix': 'B', 'entity_type': 'DATE'}
# {'text': week, 'prefix': 'I', 'entity_type': 'DATE'}
# {'text': despite, 'prefix': 'O', 'entity_type': ''}
# {'text': testing, 'prefix': 'O', 'entity_type': ''}
# {'text': positive, 'prefix': 'O', 'entity_type': ''}
# {'text': for, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': virus, 'prefix': 'O', 'entity_type': ''}
# {'text': upon, 'prefix': 'O', 'entity_type': ''}
# {'text': his, 'prefix': 'O', 'entity_type': ''}
# {'text': return, 'prefix': 'O', 'entity_type': ''}
# {'text': from, 'prefix': 'O', 'entity_type': ''}
# {'text': Saudi, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': Arabia, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': as, 'prefix': 'O', 'entity_type': ''}
# {'text': officials, 'prefix': 'O', 'entity_type': ''}
# {'text': considered, 'prefix': 'O', 'entity_type': ''}
# {'text': him, 'prefix': 'O', 'entity_type': ''}
# {'text': a, 'prefix': 'O', 'entity_type': ''}
# {'text': “, 'prefix': 'O', 'entity_type': ''}
# {'text': recovered, 'prefix': 'O', 'entity_type': ''}
# {'text': case, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': ”Even, 'prefix': 'O', 'entity_type': ''}
# {'text': Hong, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': Kong, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': ’s, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': biggest, 'prefix': 'O', 'entity_type': ''}
# {'text': optimists, 'prefix': 'O', 'entity_type': ''}
# {'text': concede, 'prefix': 'O', 'entity_type': ''}
# {'text': there, 'prefix': 'O', 'entity_type': ''}
# {'text': is, 'prefix': 'O', 'entity_type': ''}
# {'text': a, 'prefix': 'O', 'entity_type': ''}
# {'text': lot, 'prefix': 'O', 'entity_type': ''}
# {'text': of, 'prefix': 'O', 'entity_type': ''}
# {'text': work, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': be, 'prefix': 'O', 'entity_type': ''}
# {'text': done, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': namely, 'prefix': 'O', 'entity_type': ''}
# {'text': reopening, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': border, 'prefix': 'O', 'entity_type': ''}
# {'text': with, 'prefix': 'O', 'entity_type': ''}
# {'text': mainland, 'prefix': 'O', 'entity_type': ''}
# {'text': China, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': “As, 'prefix': 'O', 'entity_type': ''}
# {'text': long, 'prefix': 'O', 'entity_type': ''}
# {'text': as, 'prefix': 'O', 'entity_type': ''}
# {'text': we, 'prefix': 'O', 'entity_type': ''}
# {'text': remove, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': travel, 'prefix': 'O', 'entity_type': ''}
# {'text': restrictions, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': business, 'prefix': 'O', 'entity_type': ''}
# {'text': and, 'prefix': 'O', 'entity_type': ''}
# {'text': leisure, 'prefix': 'O', 'entity_type': ''}
# {'text': travelers, 'prefix': 'O', 'entity_type': ''}
# {'text': are, 'prefix': 'O', 'entity_type': ''}
# {'text': going, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': come, 'prefix': 'O', 'entity_type': ''}
# {'text': back, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': ”, 'prefix': 'O', 'entity_type': ''}
# {'text': said, 'prefix': 'O', 'entity_type': ''}
# {'text': Heiwai, 'prefix': 'B', 'entity_type': 'PERSON'}
# {'text': Tang, 'prefix': 'I', 'entity_type': 'PERSON'}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': an, 'prefix': 'O', 'entity_type': ''}
# {'text': economics, 'prefix': 'O', 'entity_type': ''}
# {'text': professor, 'prefix': 'O', 'entity_type': ''}
# {'text': at, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'B', 'entity_type': 'ORG'}
# {'text': University, 'prefix': 'I', 'entity_type': 'ORG'}
# {'text': of, 'prefix': 'I', 'entity_type': 'ORG'}
# {'text': Hong, 'prefix': 'I', 'entity_type': 'ORG'}
# {'text': Kong, 'prefix': 'I', 'entity_type': 'ORG'}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': “, 'prefix': 'O', 'entity_type': ''}
# {'text': and, 'prefix': 'O', 'entity_type': ''}
# {'text': then, 'prefix': 'O', 'entity_type': ''}
# {'text': we, 'prefix': 'O', 'entity_type': ''}
# {'text': ’ll, 'prefix': 'O', 'entity_type': ''}
# {'text': be, 'prefix': 'O', 'entity_type': ''}
# {'text': back, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': normal, 'prefix': 'O', 'entity_type': ''}
# {'text': I, 'prefix': 'O', 'entity_type': ''}
# {'text': would, 'prefix': 'O', 'entity_type': ''}
# {'text': say, 'prefix': 'O', 'entity_type': ''}
# {'text': very, 'prefix': 'O', 'entity_type': ''}
# {'text': quickly, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': ”, 'prefix': 'O', 'entity_type': ''}

# %% [markdown]
# ###### 1.2.2 Most frequent tokens

# %%
tokens = [token.text for token in spacy_obj]
token_counts = Counter(tokens)

print(token_counts)
# Out:
# Counter({',': 80, 'the': 73, '.': 57, 'to': 41, 'and': 39, 'a': 36, 'Kong': 34, 'in': 33, 'Hong': 32, 'of': 29, 'that': 20, '“': 19, '’s': 18, 'for': 17, '”': 16, 'as': 15, 'on': 15, 'said': 14, 'is': 13, '\xa0': 12, 'have': 12, 'business': 11, '-': 11, 'from': 10, 'law': 10, 'summit': 9, 'was': 9, 'security': 8, 'has': 8, 'with': 8, 'are': 8, 'an': 8, 'national': 7, 'Lee': 7, 'about': 7, 'been': 7, 'China': 7, 'he': 7, 'which': 7, 'it': 6, 'at': 6, 'restrictions': 6, 'people': 6, 'not': 6, 'world': 5, 'Chinese': 5, 'financial': 5, 'by': 5, '/': 5, 'Getty': 5, 'out': 5, 'Covid': 5, 'last': 5, 'report': 5, 'more': 5, '2019': 4, 'city': 4, ';': 4, 'its': 4, 'them': 4, 'who': 4, 'say': 4, 'they': 4, 'center': 4, 'Paul': 4, 'international': 4, 'there': 4, 'after': 4, 'rule': 4, 'government': 4, 'month': 4, 'The': 4, 'global': 4, 'than': 4, 'be': 4, '—': 3, '200': 3, 'finance': 3, 'stability': 3, 'some': 3, 'many': 3, 'democracy': 3, 'very': 3, 'top': 3, 'Yeung': 3, 'Bloomberg': 3, 'via': 3, 'this': 3, 'week': 3, 'Amate': 3, 'I': 3, 'doing': 3, 'back': 3, 'one': 3, 'also': 3, 'protests': 3, 'two': 3, 'Lai': 3, 'against': 3, 'businesses': 3, 'based': 3, 'still': 3, 'quarantine': 3, 'positive': 3, 'mass': 2, 'pandemic': 2, 'left': 2, 'turn': 2, 'leader': 2, 'John': 2, 'Wednesday': 2, 'where': 2, 'around': 2, 'were': 2, 'It': 2, 'given': 2, 'way': 2, 'order': 2, 'returned': 2, 'meant': 2, 'long': 2, 'again': 2, 'border': 2, 'mainland': 2, 'economic': 2, 'remains': 2, 'closed': 2, 'companies': 2, 'rights': 2, 'groups': 2, 'pro': 2, 'And': 2, 'U.S.': 2, 'return': 2, 'event': 2, 'chairman': 2, 'see': 2, 'Tuesday': 2, 'lot': 2, 'both': 2, 'million': 2, 'travel': 2, 'hub': 2, 'Asia': 2, 'cited': 2, 'coming': 2, 'those': 2, 'According': 2, 'down': 2, '%': 2, 'even': 2, 'bad': 2, 'economy': 2, 'status': 2, 'Singapore': 2, 'court': 2, 'arrested': 2, 'over': 2, 'jailed': 2, 'convicted': 2, 'activist': 2, 'Jimmy': 2, 'fraud': 2, 'charges': 2, 'United': 2, 'States': 2, 'spurious': 2, ' ': 2, 'AFP': 2, 'Images': 2, 'including': 2, 'under': 2, 'Beijing': 2, '2020': 2, 'officials': 2, 'may': 2, 'leaders': 2, 'need': 2, 'new': 2, 'Kern': 2, 'nonprofit': 2, 'group': 2, 'strong': 2, 'going': 2, 'Zeman': 2, 'you': 2, '’re': 2, 'think': 2, 'their': 2, 'Officials': 2, 'ranked': 2, 'had': 2, 'advantage': 2, 'come': 2, 'September': 2, 'But': 2, 'overseas': 2, 'arrivals': 2, 'days': 2, 'bars': 2, 'restaurants': 2, 'test': 2, 'virus': 2, 'private': 2, 'we': 2, 'HONG': 1, 'KONG': 1, 'After': 1, 'unrest': 1, 'isolated': 1, 'imposition': 1, 'crushed': 1, 'dissent': 1, 'ready': 1, 'page': 1, 'Social': 1, 'disturbance': 1, 'clearly': 1, 'past': 1, 'Four': 1, 'Seasons': 1, 'Hotel': 1, 'industry': 1, 'executives': 1, 'gathered': 1, 'growing': 1, 'community': 1, 'confidence': 1, 'future': 1, 'Law': 1, 'worst': 1, 'behind': 1, 'us': 1, '”But': 1, 'signal': 1, 'territory': 1, 'known': 1, 'regional': 1, 'powerhouse': 1, 'open': 1, 'shadowed': 1, 'awkward': 1, 'realities': 1, 'main': 1, 'driver': 1, 'tightly': 1, 'because': 1, 'Participants': 1, 'American': 1, 'criticized': 1, 'lawmakers': 1, 'complicit': 1, 'harsh': 1, 'crackdown': 1, 'figures': 1, 'subject': 1, 'sanctions': 1, 'himself': 1, 'unable': 1, 'hold': 1, 'account': 1, 'banks': 1, 'addressing': 1, 'ImagesNone': 1, 'seems': 1, 'dampened': 1, 'mood': 1, 'events': 1, 'started': 1, 'Monday': 1, 'fintech': 1, 'conference': 1, 'conclude': 1, 'weekend': 1, 'major': 1, 'sporting': 1, 'Rugby': 1, 'Sevens': 1, 'tournament': 1, 'Iñaki': 1, 'European': 1, 'Chamber': 1, 'Commerce': 1, 'upbeat': 1, 'atmosphere': 1, 'encountered': 1, 'how': 1, 'positively': 1, 'surprised': 1, 'good': 1, 'vibe': 1, 'headed': 1, 'tour': 1, 'welcome': 1, 'dinner': 1, 'M+': 1, 'art': 1, 'museum': 1, 'felt': 1, 'like': 1, 'came': 1, 'cave': 1, 'energy': 1, 'willing': 1, 'start': 1, '”The': 1, 'part': 1, 'broader': 1, 'campaign': 1, 'draw': 1, 'tourists': 1, '7.3': 1, 'built': 1, 'reputation': 1, 'bastion': 1, 'freedom': 1, 'That': 1, 'image': 1, ...

# %% [markdown]
# ###### 1.2.3 Picking a random integer K using Python random module, then pick three consecutive sentences starting with Kth sentence, and print these sentences

# %%
sentences_original = sent_tokenize(text)
# for i,k in range(0, len(sentences_original)): 
k = random.randint(0, len(sentences_original)-3)
a = []
for j, sentence in enumerate(sentences_original):
    if j == k:
        
        kth = sentences_original[k],
        kkth = sentences_original[k+1],
        kkkth = sentences_original[k+2]
        a.append(sentences_original[k]+sentences_original[k+1] + sentences_original[k+2])
        print(k,kth),
        print(k+1,kkth),
        print(k+2,kkth)
# Out:
# 6 ('And as the subject of U.S. sanctions himself, Lee is unable to hold an account with many of the very banks he was addressing.John Lee, Hong Kong’s top leader, center, at the finance summit on Wednesday.',)
# 7 ('Paul Yeung / Bloomberg via Getty ImagesNone of that seems to have dampened the mood at this week’s events, which started on Monday with a fintech conference and conclude this weekend with the return of a major international sporting event, the Rugby Sevens tournament.Iñaki Amate, chairman of the European Chamber of Commerce in Hong Kong, was upbeat about the event and the pro-business atmosphere he encountered.',)
# 8 ('Paul Yeung / Bloomberg via Getty ImagesNone of that seems to have dampened the mood at this week’s events, which started on Monday with a fintech conference and conclude this weekend with the return of a major international sporting event, the Rugby Sevens tournament.Iñaki Amate, chairman of the European Chamber of Commerce in Hong Kong, was upbeat about the event and the pro-business atmosphere he encountered.',)

# %% [markdown]
# ###### 1.2.4 Extract Part of speech and lemmatize

# %%
a_string = ' '.join([str(item) for item in a])
text1 = word_tokenize(a_string)
print('POS TAG :',nltk.pos_tag(text1))
tokenizer = RegexpTokenizer(r'\w+')
mytext = tokenizer.tokenize(a_string.lower())
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(w) for w in mytext]
print("lemmatized_words:",lemmatized_words)
# Out:
# POS TAG : [('And', 'CC'), ('as', 'IN'), ('the', 'DT'), ('subject', 'NN'), ('of', 'IN'), ('U.S.', 'NNP'), ('sanctions', 'NNS'), ('himself', 'PRP'), (',', ','), ('Lee', 'NNP'), ('is', 'VBZ'), ('unable', 'JJ'), ('to', 'TO'), ('hold', 'VB'), ('an', 'DT'), ('account', 'NN'), ('with', 'IN'), ('many', 'JJ'), ('of', 'IN'), ('the', 'DT'), ('very', 'RB'), ('banks', 'NNS'), ('he', 'PRP'), ('was', 'VBD'), ('addressing.John', 'JJ'), ('Lee', 'NNP'), (',', ','), ('Hong', 'NNP'), ('Kong', 'NNP'), ('’', 'NNP'), ('s', 'JJ'), ('top', 'JJ'), ('leader', 'NN'), (',', ','), ('center', 'NN'), (',', ','), ('at', 'IN'), ('the', 'DT'), ('finance', 'NN'), ('summit', 'NN'), ('on', 'IN'), ('Wednesday.Paul', 'NNP'), ('Yeung', 'NNP'), ('/', 'NNP'), ('Bloomberg', 'NNP'), ('via', 'IN'), ('Getty', 'NNP'), ('ImagesNone', 'NNP'), ('of', 'IN'), ('that', 'DT'), ('seems', 'VBZ'), ('to', 'TO'), ('have', 'VB'), ('dampened', 'VBN'), ('the', 'DT'), ('mood', 'NN'), ('at', 'IN'), ('this', 'DT'), ('week', 'NN'), ('’', 'NNP'), ('s', 'NN'), ('events', 'NNS'), (',', ','), ('which', 'WDT'), ('started', 'VBD'), ('on', 'IN'), ('Monday', 'NNP'), ('with', 'IN'), ('a', 'DT'), ('fintech', 'JJ'), ('conference', 'NN'), ('and', 'CC'), ('conclude', 'NN'), ('this', 'DT'), ('weekend', 'NN'), ('with', 'IN'), ('the', 'DT'), ('return', 'NN'), ('of', 'IN'), ('a', 'DT'), ('major', 'JJ'), ('international', 'JJ'), ('sporting', 'VBG'), ('event', 'NN'), (',', ','), ('the', 'DT'), ('Rugby', 'NNP'), ('Sevens', 'NNP'), ('tournament.Iñaki', 'NN'), ('Amate', 'NNP'), (',', ','), ('chairman', 'NN'), ('of', 'IN'), ('the', 'DT'), ('European', 'JJ'), ('Chamber', 'NNP'), ('of', 'IN'), ('Commerce', 'NNP'), ('in', 'IN'), ('Hong', 'NNP'), ('Kong', 'NNP'), (',', ','), ('was', 'VBD'), ('upbeat', 'JJ'), ('about', 'IN'), ('the', 'DT'), ('event', 'NN'), ('and', 'CC'), ('the', 'DT'), ('pro-business', 'NN'), ('atmosphere', 'NN'), ('he', 'PRP'), ('encountered.', 'VBZ'), ('“', 'NN'), ('I', 'PRP'), ('have', 'VBP'), ('to', 'TO'), ('say', 'VB'), ('how', 'WRB'), ('positively', 'RB'), ('surprised', 'VBD'), ('I', 'PRP'), ('was', 'VBD'), ('to', 'TO'), ('see', 'VB'), ('that', 'IN'), ('there', 'EX'), ('was', 'VBD'), ('a', 'DT'), ('very', 'RB'), ('good', 'JJ'), ('vibe', 'NN'), (',', ','), ('”', 'NNP'), ('Amate', 'NNP'), ('said', 'VBD'), ('Tuesday', 'NNP'), ('as', 'IN'), ('he', 'PRP'), ('headed', 'VBD'), ('for', 'IN'), ('a', 'DT'), ('tour', 'NN'), ('and', 'CC'), ('welcome', 'JJ'), ('dinner', 'NN'), ('at', 'IN'), ('the', 'DT'), ('M+', 'NNP'), ('art', 'NN'), ('museum', 'NN'), ('.', '.')]
# lemmatized_words: ['and', 'a', 'the', 'subject', 'of', 'u', 's', 'sanction', 'himself', 'lee', 'is', 'unable', 'to', 'hold', 'an', 'account', 'with', 'many', 'of', 'the', 'very', 'bank', 'he', 'wa', 'addressing', 'john', 'lee', 'hong', 'kong', 's', 'top', 'leader', 'center', 'at', 'the', 'finance', 'summit', 'on', 'wednesday', 'paul', 'yeung', 'bloomberg', 'via', 'getty', 'imagesnone', 'of', 'that', 'seems', 'to', 'have', 'dampened', 'the', 'mood', 'at', 'this', 'week', 's', 'event', 'which', 'started', 'on', 'monday', 'with', 'a', 'fintech', 'conference', 'and', 'conclude', 'this', 'weekend', 'with', 'the', 'return', 'of', 'a', 'major', 'international', 'sporting', 'event', 'the', 'rugby', 'seven', 'tournament', 'iñaki', 'amate', 'chairman', 'of', 'the', 'european', 'chamber', 'of', 'commerce', 'in', 'hong', 'kong', 'wa', 'upbeat', 'about', 'the', 'event', 'and', 'the', 'pro', 'business', 'atmosphere', 'he', 'encountered', 'i', 'have', 'to', 'say', 'how', 'positively', 'surprised', 'i', 'wa', 'to', 'see', 'that', 'there', 'wa', 'a', 'very', 'good', 'vibe', 'amate', 'said', 'tuesday', 'a', 'he', 'headed', 'for', 'a', 'tour', 'and', 'welcome', 'dinner', 'at', 'the', 'm', 'art', 'museum']

# %%
def tagger(sentence, nlp=nlp):

  print('')
  print('Original sentence')
  print(sentence)
  
  spacy_obj= nlp(sentence)

  #print('Entitites:')
  rows = []
  for x in spacy_obj.ents:
    rows.append(dict(text=x.text, label=x.label_, start_char=x.start_char, end_char=x.start_char+len(x.text)))

  df = pd.DataFrame(rows)
  print(df)

  # Visualize Entities
  displacy.render(spacy_obj, jupyter=True, style='ent')

# %%
tagger(a_string)
# Out:
# Original sentence
# And as the subject of U.S. sanctions himself, Lee is unable to hold an account with many of the very banks he was addressing.John Lee, Hong Kong’s top leader, center, at the finance summit on Wednesday.Paul Yeung / Bloomberg via Getty ImagesNone of that seems to have dampened the mood at this week’s events, which started on Monday with a fintech conference and conclude this weekend with the return of a major international sporting event, the Rugby Sevens tournament.Iñaki Amate, chairman of the European Chamber of Commerce in Hong Kong, was upbeat about the event and the pro-business atmosphere he encountered.“I have to say how positively surprised I was to see that there was a very good vibe,” Amate said Tuesday as he headed for a tour and welcome dinner at the M+ art museum.
#                                 text     label  start_char  end_char
# 0                               U.S.       GPE          22        26
# 1                                Lee    PERSON          46        49
# 2                           John Lee    PERSON         125       133
# 3                        Hong Kong’s       GPE         135       146
# 4                          Wednesday      DATE         192       201
# 5                         Paul Yeung    PERSON         202       212
# 6                          Bloomberg    PERSON         215       224
# 7                               week      DATE         294       298
# 8                             Monday      DATE         326       332
# 9                       this weekend      DATE         372       384
# 10                            Sevens    PERSON         452       458
# 11                       Iñaki Amate    PERSON         470       481
# 12  the European Chamber of Commerce       ORG         495       527
# 13                         Hong Kong       GPE         531       540
# 14                             Amate       ORG         703       708
# 15                           Tuesday      DATE         714       721
# 16                                M+  CARDINAL         772       774
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">And as the subject of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  sanctions himself,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is unable to hold an account with many of the very banks he was addressing.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     John Lee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hong Kong’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  top leader, center, at the finance summit on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paul Yeung
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  /
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bloomberg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  via Getty ImagesNone of that seems to have dampened the mood at this
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ’s events, which started on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  with a fintech conference and conclude
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this weekend
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  with the return of a major international sporting event, the Rugby
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sevens
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  tournament.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Iñaki Amate
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , chairman of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the European Chamber of Commerce
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hong Kong
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , was upbeat about the event and the pro-business atmosphere he encountered.“I have to say how positively surprised I was to see that there was a very good vibe,”
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amate
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  said
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  as he headed for a tour and welcome dinner at the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     M+
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  art museum.</div></span>

# %% [markdown]
# ###### 1.2.5 Entity Annoation for kth sentence

# %%
k_string = ' '.join([str(item) for item in kth])

spacy_obj1= nlp(k_string)
print('Entity Annotation of kth sentence:\n')
for x in spacy_obj1:
  print(dict(text=x, prefix=x.ent_iob_, entity_type=x.ent_type_))
# Out:
# Entity Annotation of kth sentence:
#
# {'text': And, 'prefix': 'O', 'entity_type': ''}
# {'text': as, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': subject, 'prefix': 'O', 'entity_type': ''}
# {'text': of, 'prefix': 'O', 'entity_type': ''}
# {'text': U.S., 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': sanctions, 'prefix': 'O', 'entity_type': ''}
# {'text': himself, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': Lee, 'prefix': 'B', 'entity_type': 'PERSON'}
# {'text': is, 'prefix': 'O', 'entity_type': ''}
# {'text': unable, 'prefix': 'O', 'entity_type': ''}
# {'text': to, 'prefix': 'O', 'entity_type': ''}
# {'text': hold, 'prefix': 'O', 'entity_type': ''}
# {'text': an, 'prefix': 'O', 'entity_type': ''}
# {'text': account, 'prefix': 'O', 'entity_type': ''}
# {'text': with, 'prefix': 'O', 'entity_type': ''}
# {'text': many, 'prefix': 'O', 'entity_type': ''}
# {'text': of, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': very, 'prefix': 'O', 'entity_type': ''}
# {'text': banks, 'prefix': 'O', 'entity_type': ''}
# {'text': he, 'prefix': 'O', 'entity_type': ''}
# {'text': was, 'prefix': 'O', 'entity_type': ''}
# {'text': addressing, 'prefix': 'O', 'entity_type': ''}
# {'text': ., 'prefix': 'O', 'entity_type': ''}
# {'text': John, 'prefix': 'B', 'entity_type': 'PERSON'}
# {'text': Lee, 'prefix': 'I', 'entity_type': 'PERSON'}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': Hong, 'prefix': 'B', 'entity_type': 'GPE'}
# {'text': Kong, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': ’s, 'prefix': 'I', 'entity_type': 'GPE'}
# {'text': top, 'prefix': 'O', 'entity_type': ''}
# {'text': leader, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': center, 'prefix': 'O', 'entity_type': ''}
# {'text': ,, 'prefix': 'O', 'entity_type': ''}
# {'text': at, 'prefix': 'O', 'entity_type': ''}
# {'text': the, 'prefix': 'O', 'entity_type': ''}
# {'text': finance, 'prefix': 'O', 'entity_type': ''}
# {'text': summit, 'prefix': 'O', 'entity_type': ''}
# {'text': on, 'prefix': 'O', 'entity_type': ''}
# {'text': Wednesday, 'prefix': 'B', 'entity_type': 'DATE'}
# {'text': ., 'prefix': 'O', 'entity_type': ''}

# %% [markdown]
# ###### 1.2.6.1  Visualize entities of Kth sentence

# %%
displacy.render(spacy_obj1,jupyter=True,style ='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">And as the subject of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  sanctions himself,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is unable to hold an account with many of the very banks he was addressing.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     John Lee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hong Kong’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  top leader, center, at the finance summit on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</div></span>

# %% [markdown]
# ###### 1.2.6.1  Visualize dependencies of Kth sentence

# %%
displacy.serve(spacy_obj1, style="dep")
# Out:
# C:\Users\Vikas\anaconda3\lib\site-packages\spacy\displacy\__init__.py:103: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="902aaed8b6af46ec8d95181fdea5a7c4-0" class="displacy" width="6700" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">And</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">subject</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">U.S.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">sanctions</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">himself,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Lee</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">unable</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">hold</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">account</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">many</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">very</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">banks</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">he</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">addressing.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">John</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">Lee,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">Hong</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">Kong</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">’s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x=
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %% [markdown]
# ##### 1.2.7 Visualize entities of entire document

# %%
displacy.render(spacy_obj,jupyter=True, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HONG KONG
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  — After mass unrest in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , a pandemic that left it isolated from the world and the imposition of a national security law that has crushed dissent,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hong Kong
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is ready to turn the page. “Social disturbance is clearly in the past,” the city’s leader,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     John Lee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , said
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Four Seasons Hotel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , where
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about 200
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  finance industry executives from around the world were gathered for a summit. “It has given way to stability, to growing business and community confidence in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hong Kong’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  future. Law and order has returned; the worst is behind us.”But the summit — meant to signal that the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chinese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  territory long known as a regional financial powerhouse is again open for business — has been shadowed by some awkward realities.
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hong Kong’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  border with mainland
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , its main economic driver, remains tightly closed because of pandemic restrictions. Participants in the summit, many of them
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  companies, have been criticized by rights groups and lawmakers who say they are complicit in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ’s harsh crackdown on pro-democracy figures and groups. And as the subject of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  sanctions himself,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is unable to hold an account with many of the very banks he was addressing.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     John Lee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hong Kong’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  top leader, center, at the finance summit on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paul Yeung
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  /
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bloomberg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  via Getty ImagesNone of that seems to have dampened the mood at this
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ’s events, which started on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  with a fintech

# %% [markdown]
# ### TASK-02 - Replacing the NER - PERSON to "[REDACTED]"

# %%
# !pip install re
import re

def replace_name(token):
    if token.ent_iob != 0 and token.ent_type_ == "PERSON":
        return "[REDACTED] "
    else:
        return token.text

# Loop through all the entities in a document and check if they are names
def scrub(text):
    doc = nlp(text)
    with doc.retokenize() as retokenizer:
        for ent in doc.ents:
            retokenizer.merge(ent)
    tokens = map(replace_name, doc)
    return " ".join(tokens)

redacted = scrub(text)
displacy.render(nlp(redacted), style="ent")
# Out:
# ERROR: Could not find a version that satisfies the requirement re (from versions: none)
# ERROR: No matching distribution found for re
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HONG KONG
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  — After mass unrest in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2019
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  , a pandemic that left it isolated from the world and the imposition of a national security law that has crushed dissent ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hong Kong
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is ready to turn the page .   “ Social disturbance is clearly in the past , ” the city ’s leader , [REDACTED]  , said
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Four Seasons Hotel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  , where
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about 200
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  finance industry executives from around the world were gathered for a summit . “ It has given way to stability , to growing business and community confidence in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hong Kong’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  future . Law and order has returned ; the worst is behind us . ”But the summit — meant to signal that the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chinese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  territory long known as a regional financial powerhouse is again open for business — has been shadowed by some awkward realities .
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hong Kong’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  border with mainland
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  , its main economic driver , remains tightly closed because of pandemic restrictions . Participants in the summit , many of them
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  companies , have been criticized by rights groups and lawmakers who say they are complicit in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  ’s harsh crackdown on pro - democracy figures and groups . And as the subject of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  sanctions himself , [REDACTED]  is unable to hold an account with many of the very banks he was addressing . [REDACTED]  ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hong Kong’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  top leader , center , at the finance summit on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  . [REDACTED]  / [REDACTED]  via Getty ImagesNone of that seems to have dampened the mood at this
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  ’s events , which started on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  with a fintech conference and conclude
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this weekend
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  with the return of a major international sporting event , the Rugby [REDACTED]  tournament . [REDACTED]  , chairman of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the European Chamber of Commerce
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hong Kong
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  , was upbeat about the event and the pro - business atmosphere he encountered .   “ I have to say how positively surprised I was to see that there was a very good vibe , ”
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amate
#     <span style="font-size:
